# %%
# basics
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
import os
from collections import Counter
# import copy
import seaborn as sns
from time import time
from datetime import timedelta
import warnings
warnings.filterwarnings('ignore')

# sklearn
from sklearn import preprocessing
from sklearn.metrics import log_loss
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer
from sklearn.decomposition import PCA
from sklearn.feature_selection import VarianceThreshold
from sklearn.cluster import KMeans
from sklearn.model_selection import KFold

# pyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.nn.modules.loss import _WeightedLoss

# stratified kfold
# !pip install /kaggle/input/iterative-stratification/iterative-stratification-master/
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold
# Out:
# Processing /kaggle/input/iterative-stratification/iterative-stratification-master
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from iterative-stratification==0.1.6) (1.18.5)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from iterative-stratification==0.1.6) (1.4.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.7/site-packages (from iterative-stratification==0.1.6) (0.23.2)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from scikit-learn->iterative-stratification==0.1.6) (0.14.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn->iterative-stratification==0.1.6) (2.1.0)
# Building wheels for collected packages: iterative-stratification
# done
#   Created wheel for iterative-stratification: filename=iterative_stratification-0.1.6-py3-none-any.whl size=8401 sha256=49869fdbc6f5a3b39988b66fadf657caf6f2f4e1b381a40eb20196f0cef7bd9d
#   Stored in directory: /root/.cache/pip/wheels/b8/47/3f/eb4af42d124f37d23d6f13a4c8bbc32c1d70140e6e1cecb4aa
# Successfully built iterative-stratification
# Installing collected packages: iterative-stratification
# Successfully installed iterative-stratification-0.1.6

# %%
# load raw data
data_dir = '../input/lish-moa/'
train_features = pd.read_csv(data_dir + 'train_features.csv')
train_targets_scored = pd.read_csv(data_dir + 'train_targets_scored.csv')
train_targets_nonscored = pd.read_csv(data_dir + 'train_targets_nonscored.csv')
train_drug = pd.read_csv(data_dir + 'train_drug.csv')
test_features = pd.read_csv(data_dir + 'test_features.csv')
sample_submission = pd.read_csv(data_dir + 'sample_submission.csv')

train_features_extra = pd.read_csv('../input/moa-fe-extra-data/MoA_FE_Extra_Data.csv')

# keep only nonscored targets with >0 positive labels
keep_list = (np.where(train_targets_nonscored.iloc[:,1:].values.sum(axis=0)>0)[0] + 1).tolist()
train_targets_nonscored = train_targets_nonscored.iloc[:,[0]+keep_list]

print('train_features: {}'.format(train_features.shape))
print('train_targets_scored: {}'.format(train_targets_scored.shape))
print('train_targets_nonscored: {}'.format(train_targets_nonscored.shape))
print('train_drug: {}'.format(train_drug.shape))
print('test_features: {}'.format(test_features.shape))
print('fe_extra_features: {}'.format(fe_extra_features.shape))
print('sample_submission: {}'.format(sample_submission.shape))
# Out:
# train_features: (23814, 876)
# train_targets_scored: (23814, 207)
# train_targets_nonscored: (23814, 332)
# train_drug: (23814, 2)
# test_features: (3982, 876)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-bd289a00333d> in <module>
#      19 print('train_drug: {}'.format(train_drug.shape))
#      20 print('test_features: {}'.format(test_features.shape))
# ---> 21 print('fe_extra_features: {}'.format(fe_extra_features.shape))
#      22 print('sample_submission: {}'.format(sample_submission.shape))
#
# NameError: name 'fe_extra_features' is not defined

# %%
# function to set single seed for everything
def seed_everything(seed_value):
    random.seed(seed_value)
    np.random.seed(seed_value)
    torch.manual_seed(seed_value)

    if torch.cuda.is_available(): 
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

# set seed to 42
seed_everything(42)

# %% [markdown]
# # Feature Engineering

# %%
# define g/c features
g_col = [col for col in train_features.columns if col.startswith('g-')]
c_col = [col for col in train_features.columns if col.startswith('c-')]

# %%
def feature_engineering(x_train, x_test, seed):
    
    # set seed
    seed_everything(seed)

    # sig_id & cp_type
    sig_train = x_train[['sig_id', 'cp_type']]
    sig_test = x_test[['sig_id', 'cp_type']]
    print('sig_id & cp_type', sig_train.shape, sig_test.shape)
    
    # OHE for cp_time, cp_dose
    cp_dose = {'D1': 0, 'D2': 1}
    cp_time = {24:0, 48:1, 72:2}
    cp_dose_train = x_train.cp_dose.map(cp_dose)
    cp_time_train = x_train.cp_time.map(cp_time)
    cp_dose_test = x_test.cp_dose.map(cp_dose)
    cp_time_test = x_test.cp_time.map(cp_time)
    cp_train = pd.DataFrame({'cp_dose':cp_dose_train, 'cp_time':cp_time_train}).reset_index(drop=True)
    cp_test = pd.DataFrame({'cp_dose':cp_dose_test, 'cp_time':cp_time_test}).reset_index(drop=True)
    print('OHE for cp_time, cp_dose', cp_train.shape, cp_test.shape)
    
    # RankGauss scaling
    n_quantiles = 100
    qt = QuantileTransformer(n_quantiles=n_quantiles, random_state=seed, output_distribution='normal').fit(x_train[g_col + c_col])
    rg_train = pd.DataFrame(qt.transform(x_train[g_col + c_col]), columns=['rg_' + col for col in g_col + c_col]).reset_index(drop=True)
    rg_test = pd.DataFrame(qt.transform(x_test[g_col + c_col]), columns=['rg_' + col for col in g_col + c_col]).reset_index(drop=True)
    print('RankGauss scaling', rg_train.shape, rg_test.shape)
    print(rg_train.head())
    
    # PCA for g_col
    g_n_comp = 600
    rg_g_col = [col for col in rg_train.columns if col.startswith('rg_g')]
    pca = PCA(n_components=g_n_comp, random_state=seed).fit(rg_train[rg_g_col])
    pca_g_train = pd.DataFrame(pca.transform(rg_train[rg_g_col]), columns=['pca_g-' + str(i) for i in range(g_n_comp)]).reset_index(drop=True)
    pca_g_test = pd.DataFrame(pca.transform(rg_test[rg_g_col]), columns=['pca_g-' + str(i) for i in range(g_n_comp)]).reset_index(drop=True)
    print('PCA for g_col', pca_g_train.shape, pca_g_test.shape)
    print(pca_g_train.head())

    # PCA for c_col
    c_n_comp = 50
    rg_c_col = [col for col in rg_train.columns if col.startswith('rg_c')]
    pca = PCA(n_components=c_n_comp, random_state=seed).fit(rg_train[rg_c_col])
    pca_c_train = pd.DataFrame(pca.transform(rg_train[rg_c_col]), columns=['pca_c-' + str(i) for i in range(c_n_comp)]).reset_index(drop=True)
    pca_c_test = pd.DataFrame(pca.transform(rg_test[rg_c_col]), columns=['pca_c-' + str(i) for i in range(c_n_comp)]).reset_index(drop=True)
    print('PCA for c_col', pca_c_train.shape, pca_c_test.shape)
    print(pca_c_train.head())

    # combine g & c PCA features
    pca_gc_train = pd.concat((pca_g_train, pca_c_train),axis=1).reset_index(drop=True)
    pca_gc_test  =pd.concat((pca_g_test, pca_c_test),axis=1).reset_index(drop=True)
    print('combine g & c PCA features', pca_gc_train.shape, pca_gc_test.shape)
    print(pca_gc_train.head())

    # FS by Variance Threshold
    thsld = 0.85
    data_train = pd.concat([rg_train, pca_gc_train], axis=1)
    data_test = pd.concat([rg_test, pca_gc_test], axis=1)
    variance_threshold = VarianceThreshold(thsld).fit(data_train)
    selected_features = variance_threshold.get_support(True).tolist()
    fs_train = data_train.iloc[:,selected_features].reset_index(drop=True)
    fs_test = data_test.iloc[:,selected_features].reset_index(drop=True)
    print('FS by Variance Threshold', fs_train.shape, fs_test.shape)
    print(fs_train.head())

    # function to cluster raw g/c
    n_clusters_g = 22
    n_clusters_c = 4
    def gc_cluster(train, test, n_clusters_g, n_clusters_c, seed):

        def create_cluster(train, test, features, kind, n_clusters):
            col_prefix = 'raw_clusters_'
            train_ = train[features].copy()
            test_ = test[features].copy()
            kmeans = KMeans(n_clusters=n_clusters, random_state=seed).fit(train_)
            data = pd.concat([train_, test_], axis=0).reset_index(drop=True)
            pred = pd.DataFrame(kmeans.predict(data[features]), columns=[col_prefix + kind])
            pred = pd.get_dummies(pred, columns=[col_prefix + kind])
            pred_train = pred.iloc[:len(train),:].reset_index(drop=True)
            pred_test = pred.iloc[len(train):,:].reset_index(drop=True)
            return pred_train, pred_test

        g_pred_train, g_pred_test = create_cluster(train, test, g_col, kind='g', n_clusters=n_clusters_g)
        c_pred_train, c_pred_test = create_cluster(train, test, c_col, kind='c', n_clusters=n_clusters_c)
        gc_pred_train = pd.concat([g_pred_train, c_pred_train], axis=1).reset_index(drop=True)
        gc_pred_test = pd.concat([g_pred_test, c_pred_test], axis=1).reset_index(drop=True)
        return gc_pred_train, gc_pred_test
    
    raw_gc_cluster_train, raw_gc_cluster_test = gc_cluster(x_train, x_test, n_clusters_g=n_clusters_g, n_clusters_c=n_clusters_c, seed=seed)
    print('cluster raw g/c', raw_gc_cluster_train.shape, raw_gc_cluster_test.shape)


    # function to cluster PCA g/c
    n_clusters = 5
    def fe_cluster_pca(train, test, n_clusters, seed):
        col_prefix = 'pca_clusters'
        kmeans = KMeans(n_clusters=n_clusters, random_state = seed).fit(train)
        data = pd.concat([train, test], axis=0).reset_index(drop=True)
        pred = pd.DataFrame(kmeans.predict(data), columns=[col_prefix])
        pred = pd.get_dummies(pred, columns=[col_prefix])
        pred_train = pred.iloc[:len(train),:].reset_index(drop=True)
        pred_test = pred.iloc[len(train):,:].reset_index(drop=True)
        return pred_train, pred_test
    pca_cluster_train, pca_cluster_test = fe_cluster_pca(pca_gc_train, pca_gc_test, n_clusters=n_clusters, seed=seed)
    print('cluster PCA g/c', pca_cluster_train.shape, pca_cluster_test.shape)


    # statistics features
    gsquarecols = ['g-574','g-211','g-216','g-0','g-255','g-577','g-153','g-389','g-60','g-370','g-248','g-167','g-203',
                   'g-177','g-301','g-332','g-517','g-6','g-744','g-224','g-162','g-3','g-736','g-486','g-283','g-22',
                   'g-359','g-361','g-440','g-335','g-106','g-307','g-745','g-146','g-416','g-298','g-666','g-91','g-17',
                   'g-549','g-145','g-157','g-768','g-568','g-396']
    def fe_stats(df):
        stat_df = dict()
        stat_df['g_sum'] = df[g_col].sum(axis = 1)
        stat_df['g_mean'] = df[g_col].mean(axis = 1)
        stat_df['g_std'] = df[g_col].std(axis = 1)
        stat_df['g_kurt'] = df[g_col].kurtosis(axis = 1)
        stat_df['g_skew'] = df[g_col].skew(axis = 1)
        stat_df['c_sum'] = df[c_col].sum(axis = 1)
        stat_df['c_mean'] = df[c_col].mean(axis = 1)
        stat_df['c_std'] = df[c_col].std(axis = 1)
        stat_df['c_kurt'] = df[c_col].kurtosis(axis = 1)
        stat_df['c_skew'] = df[c_col].skew(axis = 1)
        stat_df['gc_sum'] = df[g_col + c_col].sum(axis = 1)
        stat_df['gc_mean'] = df[g_col + c_col].mean(axis = 1)
        stat_df['gc_std'] = df[g_col + c_col].std(axis = 1)
        stat_df['gc_kurt'] = df[g_col + c_col].kurtosis(axis = 1)
        stat_df['gc_skew'] = df[g_col + c_col].skew(axis = 1)

        stat_df['c52_c42'] = df['c-52'] * df['c-42']
        stat_df['c13_c73'] = df['c-13'] * df['c-73']
        stat_df['c26_c13'] = df['c-23'] * df['c-13']
        stat_df['c33_c6'] = df['c-33'] * df['c-6']
        stat_df['c11_c55'] = df['c-11'] * df['c-55']
        stat_df['c38_c63'] = df['c-38'] * df['c-63']
        stat_df['c38_c94'] = df['c-38'] * df['c-94']
        stat_df['c13_c94'] = df['c-13'] * df['c-94']
        stat_df['c4_c52'] = df['c-4'] * df['c-52']
        stat_df['c4_c42'] = df['c-4'] * df['c-42']
        stat_df['c13_c38'] = df['c-13'] * df['c-38']
        stat_df['c55_c2'] = df['c-55'] * df['c-2']
        stat_df['c55_c4'] = df['c-55'] * df['c-4']
        stat_df['c4_c13'] = df['c-4'] * df['c-13']
        stat_df['c82_c42'] = df['c-82'] * df['c-42']
        stat_df['c66_c42'] = df['c-66'] * df['c-42']
        stat_df['c6_c38'] = df['c-6'] * df['c-38']
        stat_df['c2_c13'] = df['c-2'] * df['c-13']
        stat_df['c62_c42'] = df['c-62'] * df['c-42']
        stat_df['c90_c55'] = df['c-90'] * df['c-55']
        
        for feature in c_col:
            stat_df[f'{feature}_squared'] = df[feature] ** 2     
        for feature in gsquarecols:
            stat_df[f'{feature}_squared'] = df[feature] ** 2  
            
        stat_df = pd.DataFrame(stat_df)
        return stat_df

    stat_train, stat_test = fe_stats(x_train), fe_stats(x_test)
    print('statistics features', stat_train.shape, stat_test.shape)

    # combine all FE results
    x_train_fe = pd.concat([sig_train, cp_train, fs_train, raw_gc_cluster_train, pca_cluster_train, stat_train], axis=1).reset_index(drop=True)
    x_test_fe = pd.concat([sig_test, cp_test, fs_test, raw_gc_cluster_test, pca_cluster_test, stat_test], axis=1).reset_index(drop=True)
    print('combine all FE results', x_train_fe.shape, x_test_fe.shape)

    # remove ctrl in train and test
    x_train_fe = x_train_fe[x_train_fe.cp_type!='ctl_vehicle']
    x_test_fe = x_test_fe[x_test_fe.cp_type!='ctl_vehicle']
    x_train_fe = x_train_fe.drop('cp_type', axis=1).reset_index(drop=True)
    x_test_fe = x_test_fe.drop('cp_type', axis=1).reset_index(drop=True)
    print('remove ctrl in train and test', x_train_fe.shape, x_test_fe.shape)

    return x_train_fe, x_test_fe

# %%
# FE parameter estimation based on provided train and test
fe_data = train_features.append(train_features_extra).reset_index(drop=True)
_, x_train_fe = feature_engineering(fe_data, train_features, seed=42)
_, x_test_fe = feature_engineering(fe_data, test_features, seed=42)
# Out:
# sig_id & cp_type (27796, 2) (23814, 2)
# OHE for cp_time, cp_dose (27796, 2) (23814, 2)
# RankGauss scaling (27796, 872) (23814, 872)
#      rg_g-0    rg_g-1    rg_g-2    rg_g-3    rg_g-4    rg_g-5    rg_g-6  \
# 0  1.146806  0.902075 -0.418339 -0.961202 -0.254770 -1.021300 -1.369236
# 1  0.128824  0.676862  0.274345  0.090495  1.208863  0.688965  0.316734
# 2  0.790372  0.939951  1.428097 -0.121817 -0.002067  1.495091  0.238763
# 3 -0.729866 -0.277163 -0.441200  0.766612  2.347817 -0.862761 -2.308829
# 4 -0.444558 -0.481202  0.974729  0.977467  1.468304 -0.874772 -0.372682
#
#      rg_g-7    rg_g-8    rg_g-9  ...   rg_c-90   rg_c-91   rg_c-92   rg_c-93  \
# 0 -0.029888  0.684319 -0.316668  ...  0.405455  0.362189  1.296097  0.830281
# 1  0.556428 -0.539718  0.831972  ... -0.527074  1.127076  0.716060  0.047538
# 2  0.363471 -0.003611  1.237966  ... -0.834469 -0.747431  0.952950  0.046551
# 3  0.305225 -0.191898 -1.389591  ... -1.429097 -0.762287 -1.653318 -1.259768
# 4 -0.212171 -1.067075  0.844018  ...  0.013943  0.000436  1.049064  1.677765
#
#     rg_c-94   rg_c-95   rg_c-96   rg_c-97   rg_c-98   rg_c-99
# 0 -0.242026  1.015974 -0.506553  0.311033  0.537989  0.644894
# 1  0.410130  0.741295  0.200866  0.175029  0.914180  1.163177
# 2 -1.221419 -0.391112 -0.763788 -0.282154 -1.132628  1.086688
# 3 -0.949084 -1.235487 -1.327725 -0.983066 -0.489388 -0.921288
# 4  0.792976 -0.374676  0.144687  0.422382 -0.479788  1.118644
#
# [5 rows x 872 columns]
# PCA for g_col (27796, 600) (23814, 600)
#      pca_g-0   pca_g-1    pca_g-2   pca_g-3   pca_g-4   pca_g-5   pca_g-6  \
# 0  -5.509135  3.934672   9.358451 -7.911861  4.834325  0.834668  3.446985
# 1  -4.899750  3.891428 -11.376574  5.777669  0.924188  0.258293  1.041124
# 2   1.258620 -7.242684  -5.448532 -0.802672  0.922407  3.698523 -1.905278
# 3  11.514493 -8.717475  -4.263702 -5.765282 -7.029854 -2.680401 -2.229116
# 4  -6.541055 -2.337753 -10.742705 -4.184780 -8.086348 -8.202837 -4.266611
#
#     pca_g-7   pca_g-8   pca_g-9  ...  pca_g-590  pca_g-591  pca_g-592  \
# 0  1.625308  0.909537  2.112349  ...  -0.261101  -0.267146   0.094667
# 1 -0.395364  5.401568  1.449645  ...   0.133985   0.348230   0.365515
# 2  2.625305 -4.668135  0.999668  ...  -0.718121   0.514602   0.379937
# 3  6.561454 -2.617044 -3.505768  ...   0.214487  -0.255354  -0.298730
# 4 -3.182038 -1.694953  0.846413  ...  -0.450802   0.543815   0.288151
#
#    pca_g-593  pca_g-594  pca_g-595  pca_g-596  pca_g-597  pca_g-598  pca_g-599
# 0  -0.444712  -0.577729   0.742372  -0.044207   0.617055  -0.827434  -0.597338
# 1  -0.447731  -0.161037  -0.503646   0.530030  -0.139655  -0.000327  -0.720127
# 2  -0.296317  -0.516916   0.495590   0.534278  -0.309372  -0.167897  -0.579945
# 3   0.117346  -0.357698   0.612286  -0.225600   0.540211  -0.695109  -0.110380
# 4   0.466401   0.956564  -1.072397   0.125651   0.039468   0.031654   0.271205
#
# [5 rows x 600 columns]
# PCA for c_col (27796, 50) (23814, 50)
#      pca_c-0   pca_c-1   pca_c-2   pca_c-3   pca_c-4   pca_c-5   pca_c-6  \
# 0   4.883810  1.541913  1.541407  1.170438  0.913066 -1.064601 -0.229895
# 1   5.052956 -0.364877 -0.023767  1.002043 -0.532869  0.673775 -0.265609
# 2  -1.394569  0.297261  0.311774 -0.215324 -0.111797 -0.704118  0.870198
# 3 -10.982825  1.162351  0.965166 -1.574983  0.006538 -1.255822 -0.380491
# 4   3.601949  0.563094  0.661240 -0.286989  0.275704  0.276489  0.273743
#
#     pca_c-7   pca_c-8   pca_c-9  ...  pca_c-40  pca_c-41  pca_c-42  pca_c-43  \
# 0  0.245207 -0.203822 -0.247286  ...  1.022747  0.053285  0.084907 -0.713952
# 1  0.579524 -1.129011 -0.566306  ... -0.148144  0.757945 -0.499426 -2.088076
# 2  0.119079 -1.111456 -0.295108  ...  1.386148  0.380597  0.126058 -0.853998
# 3  0.484322 -0.491942 -1.219179  ... -0.461107  0.003969 -0.584589  0.086056
# 4 -0.074826 -0.463755  0.189143  ...  1.298892  1.581579 -1.718438  0.290933
#
#    pca_c-44  pca_c-45  pca_c-46  pca_c-47  pca_c-48  pca_c-49
# 0  0.702275  0.043939  0.073076 -0.993137  0.243027 -0.649340
# 1 -0.390706 -0.709233 -0.086954  0.187834 -0.310141 -1.098846
# 2  0.323159 -1.624025 -0.367120 -0.471088  0.110340 -0.682874
# 3  0.303467 -0.525889 -0.291779  0.359110  0.044018  0.621962
# 4  0.673369  0.290054 -0.427830  1.561615 -0.137392  0.540456
#
# [5 rows x 50 columns]
# combine g & c PCA features (27796, 650) (23814, 650)
#      pca_g-0   pca_g-1    pca_g-2   pca_g-3   pca_g-4   pca_g-5   pca_g-6  \
# 0  -5.509135  3.934672   9.358451 -7.911861  4.834325  0.834668  3.446985
# 1  -4.899750  3.891428 -11.376574  5.777669  0.924188  0.258293  1.041124
# 2   1.258620 -7.242684  -5.448532 -0.802672  0.922407  3.698523 -1.905278
# 3  11.514493 -8.717475  -4.263702 -5.765282 -7.029854 -2.680401 -2.229116
# 4  -6.541055 -2.337753 -10.742705 -4.184780 -8.086348 -8.202837 -4.266611
#
#     pca_g-7   pca_g-8   pca_g-9  ...  pca_c-40  pca_c-41  pca_c-42  pca_c-43  \
# 0  1.625308  0.909537  2.112349  ...  1.022747  0.053285  0.084907 -0.713952
# 1 -0.395364  5.401568  1.449645  ... -0.148144  0.757945 -0.499426 -2.088076
# 2  2.625305 -4.668135  0.999668  ...  1.386148  0.380597  0.126058 -0.853998
# 3  6.561454 -2.617044 -3.505768  ... -0.461107  0.003969 -0.584589  0.086056
# 4 -3.182038 -1.694953  0.846413  ...  1.298892  1.581579 -1.718438  0.290933
#
#    pca_c-44  pca_c-45  pca_c-46  pca_c-47  pca_c-48  pca_c-49
# 0  0.702275  0.043939  0.073076 -0.993137  0.243027 -0.649340
# 1 -0.390706 -0.709233 -0.086954  0.187834 -0.310141 -1.098846
# 2  0.323159 -1.624025 -0.367120 -0.471088  0.110340 -0.682874
# 3  0.303467 -0.525889 -0.291779  0.359110  0.044018  0.621962
# 4  0.673369  0.290054 -0.427830  1.561615 -0.137392  0.540456
#
# [5 rows x 650 columns]
# FS by Variance Threshold (27796, 1024) (23814, 1024)
#      rg_g-0    rg_g-1    rg_g-2    rg_g-3    rg_g-4    rg_g-5    rg_g-6  \
# 0  1.146806  0.902075 -0.418339 -0.961202 -0.254770 -1.021300 -1.369236
# 1  0.128824  0.676862  0.274345  0.090495  1.208863  0.688965  0.316734
# 2  0.790372  0.939951  1.428097 -0.121817 -0.002067  1.495091  0.238763
# 3 -0.729866 -0.277163 -0.441200  0.766612  2.347817 -0.862761 -2.308829
# 4 -0.444558 -0.481202  0.974729  0.977467  1.468304 -0.874772 -0.372682
#
#      rg_g-7    rg_g-8    rg_g-9  ...  pca_g-142  pca_g-143  pca_g-144  \
# 0 -0.029888  0.684319 -0.316668  ...   0.735437  -0.033264  -0.025932
# 1  0.556428 -0.539718  0.831972  ...  -1.113827   0.952059   1.285865
# 2  0.363471 -0.003611  1.237966  ...   0.513153   1.179780   0.965568
# 3  0.305225 -0.191898 -1.389591  ...  -0.158321  -0.251697   1.203968
# 4 -0.212171 -1.067075  0.844018  ...  -1.322770  -0.215600  -0.859833
#
#      pca_c-0   pca_c-1   pca_c-2   pca_c-3   pca_c-4   pca_c-5   pca_c-6
# 0   4.883810  1.541913  1.541407  1.170438  0.913066 -1.064601 -0.229895
# 1   5.052956 -0.364877 -0.023767  1.002043 -0.532869  0.673775 -0.265609
# 2  -1.394569  0.297261  0.311774 -0.215324 -0.111797 -0.704118  0.870198
# 3 -10.982825  1.162351  0.965166 -1.574983  0.006538 -1.255822 -0.380491
# 4   3.601949  0.563094  0.661240 -0.286989  0.275704  0.276489  0.273743
#
# [5 rows x 1024 columns]
# cluster raw g/c (27796, 26) (23814, 26)
# cluster PCA g/c (27796, 5) (23814, 5)
# statistics features (27796, 180) (23814, 180)
# combine all FE results (27796, 1239) (23814, 1239)
# remove ctrl in train and test (25572, 1238) (21948, 1238)
# sig_id & cp_type (27796, 2) (3982, 2)
# OHE for cp_time, cp_dose (27796, 2) (3982, 2)
# RankGauss scaling (27796, 872) (3982, 872)
#      rg_g-0    rg_g-1    rg_g-2    rg_g-3    rg_g-4    rg_g-5    rg_g-6  \
# 0  1.146806  0.902075 -0.418339 -0.961202 -0.254770 -1.021300 -1.369236
# 1  0.128824  0.676862  0.274345  0.090495  1.208863  0.688965  0.316734
# 2  0.790372  0.939951  1.428097 -0.121817 -0.002067  1.495091  0.238763
# 3 -0.729866 -0.277163 -0.441200  0.766612  2.347817 -0.862761 -2.308829
# 4 -0.444558 -0.481202  0.974729  0.977467  1.468304 -0.874772 -0.372682
#
#      rg_g-7    rg_g-8    rg_g-9  ...   rg_c-90   rg_c-91   rg_c-92   rg_c-93  \
# 0 -0.029888  0.684319 -0.316668  ...  0.405455  0.362189  1.296097  0.830281
# 1  0.556428 -0.539718  0.831972  ... -0.527074  1.127076  0.716060  0.047538
# 2  0.363471 -0.003611  1.237966  ... -0.834469 -0.747431  0.952950  0.046551
# 3  0.305225 -0.191898 -1.389591  ... -1.429097 -0.762287 -1.653318 -1.259768
# 4 -0.212171 -1.067075  0.844018  ...  0.013943  0.000436  1.049064  1.677765
#
#     rg_c-94   rg_c-95   rg_c-96   rg_c-97   rg_c-98   rg_c-99
# 0 -0.242026  1.015974 -0.506553  0.311033  0.537989  0.644894
# 1  0.410130  0.741295  0.200866  0.175029  0.914180  1.163177
# 2 -1.221419 -0.391112 -0.763788 -0.282154 -1.132628  1.086688
# 3 -0.949084 -1.235487 -1.327725 -0.983066 -0.489388 -0.921288
# 4  0.792976 -0.374676  0.144687  0.422382 -0.479788  1.118644
#
# [5 rows x 872 columns]
# PCA for g_col (27796, 600) (3982, 600)
#      pca_g-0   pca_g-1    pca_g-2   pca_g-3   pca_g-4   pca_g-5   pca_g-6  \
# 0  -5.509135  3.934672   9.358451 -7.911861  4.834325  0.834668  3.446985
# 1  -4.899750  3.891428 -11.376574  5.777669  0.924188  0.258293  1.041124
# 2   1.258620 -7.242684  -5.448532 -0.802672  0.922407  3.698523 -1.905278
# 3  11.514493 -8.717475  -4.263702 -5.765282 -7.029854 -2.680401 -2.229116
# 4  -6.541055 -2.337753 -10.742705 -4.184780 -8.086348 -8.202837 -4.266611
#
#     pca_g-7   pca_g-8   pca_g-9  ...  pca_g-590  pca_g-591  pca_g-592  \
# 0  1.625308  0.909537  2.112349  ...  -0.261101  -0.267146   0.094667
# 1 -0.395364  5.401568  1.449645  ...   0.133985   0.348230   0.365515
# 2  2.625305 -4.668135  0.999668  ...  -0.718121   0.514602   0.379937
# 3  6.561454 -2.617044 -3.505768  ...   0.214487  -0.255354  -0.298730
# 4 -3.182038 -1.694953  0.846413  ...  -0.450802   0.543815   0.288151
#
#    pca_g-593  pca_g-594  pca_g-595  pca_g-596  pca_g-597  pca_g-598  pca_g-599
# 0  -0.444712  -0.577729   0.742372  -0.044207   0.617055  -0.827434  -0.597338
# 1  -0.447731  -0.161037  -0.503646   0.530030  -0.139655  -0.000327  -0.720127
# 2  -0.296317  -0.516916   0.495590   0.534278  -0.309372  -0.167897  -0.579945
# 3   0.117346  -0.357698   0.612286  -0.225600   0.540211  -0.695109  -0.110380
# 4   0.466401   0.956564  -1.072397   0.125651   0.039468   0.031654   0.271205
#
# [5 rows x 600 columns]
# PCA for c_col (27796, 50) (3982, 50)
#      pca_c-0   pca_c-1   pca_c-2   pca_c-3   pca_c-4   pca_c-5   pca_c-6  \
# 0   4.883810  1.541913  1.541407  1.170438  0.913066 -1.064601 -0.229895
# 1   5.052956 -0.364877 -0.023767  1.002043 -0.532869  0.673775 -0.265609
# 2  -1.394569  0.297261  0.311774 -0.215324 -0.111797 -0.704118  0.870198
# 3 -10.982825  1.162351  0.965166 -1.574983  0.006538 -1.255822 -0.380491
# 4   3.601949  0.563094  0.661240 -0.286989  0.275704  0.276489  0.273743
#
#     pca_c-7   pca_c-8   pca_c-9  ...  pca_c-40  pca_c-41  pca_c-42  pca_c-43  \
# 0  0.245207 -0.203822 -0.247286  ...  1.022747  0.053285  0.084907 -0.713952
# 1  0.579524 -1.129011 -0.566306  ... -0.148144  0.757945 -0.499426 -2.088076
# 2  0.119079 -1.111456 -0.295108  ...  1.386148  0.380597  0.126058 -0.853998
# 3  0.484322 -0.491942 -1.219179  ... -0.461107  0.003969 -0.584589  0.086056
# 4 -0.074826 -0.463755  0.189143  ...  1.298892  1.581579 -1.718438  0.290933
#
#    pca_c-44  pca_c-45  pca_c-46  pca_c-47  pca_c-48  pca_c-49
# 0  0.702275  0.043939  0.073076 -0.993137  0.243027 -0.649340
# 1 -0.390706 -0.709233 -0.086954  0.187834 -0.310141 -1.098846
# 2  0.323159 -1.624025 -0.367120 -0.471088  0.110340 -0.682874
# 3  0.303467 -0.525889 -0.291779  0.359110  0.044018  0.621962
# 4  0.673369  0.290054 -0.427830  1.561615 -0.137392  0.540456
#
# [5 rows x 50 columns]
# combine g & c PCA features (27796, 650) (3982, 650)
#      pca_g-0   pca_g-1    pca_g-2   pca_g-3   pca_g-4   pca_g-5   pca_g-6  \
# 0  -5.509135  3.934672   9.358451 -7.911861  4.834325  0.834668  3.446985
# 1  -4.899750  3.891428 -11.376574  5.777669  0.924188  0.258293  1.041124
# 2   1.258620 -7.242684  -5.448532 -0.802672  0.922407  3.698523 -1.905278
# 3  11.514493 -8.717475  -4.263702 -5.765282 -7.029854 -2.680401 -2.229116
# 4  -6.541055 -2.337753 -10.742705 -4.184780 -8.086348 -8.202837 -4.266611
#
#     pca_g-7   pca_g-8   pca_g-9  ...  pca_c-40  pca_c-41  pca_c-42  pca_c-43  \
# 0  1.625308  0.909537  2.112349  ...  1.022747  0.053285  0.084907 -0.713952
# 1 -0.395364  5.401568  1.449645  ... -0.148144  0.757945 -0.499426 -2.088076
# 2  2.625305 -4.668135  0.999668  ...  1.386148  0.380597  0.126058 -0.853998
# 3  6.561454 -2.617044 -3.505768  ... -0.461107  0.003969 -0.584589  0.086056
# 4 -3.182038 -1.694953  0.846413  ...  1.298892  1.581579 -1.718438  0.290933
#
#    pca_c-44  pca_c-45  pca_c-46  pca_c-47  pca_c-48  pca_c-49
# 0  0.702275  0.043939  0.073076 -0.993137  0.243027 -0.649340
# 1 -0.390706 -0.709233 -0.086954  0.187834 -0.310141 -1.098846
# 2  0.323159 -1.624025 -0.367120 -0.471088  0.110340 -0.682874
# 3  0.303467 -0.525889 -0.291779  0.359110  0.044018  0.621962
# 4  0.673369  0.290054 -0.427830  1.561615 -0.137392  0.540456
#
# [5 rows x 650 columns]
# FS by Variance Threshold (27796, 1024) (3982, 1024)
#      rg_g-0    rg_g-1    rg_g-2    rg_g-3    rg_g-4    rg_g-5    rg_g-6  \
# 0  1.146806  0.902075 -0.418339 -0.961202 -0.254770 -1.021300 -1.369236
# 1  0.128824  0.676862  0.274345  0.090495  1.208863  0.688965  0.316734
# 2  0.790372  0.939951  1.428097 -0.121817 -0.002067  1.495091  0.238763
# 3 -0.729866 -0.277163 -0.441200  0.766612  2.347817 -0.862761 -2.308829
# 4 -0.444558 -0.481202  0.974729  0.977467  1.468304 -0.874772 -0.372682
#
#      rg_g-7    rg_g-8    rg_g-9  ...  pca_g-142  pca_g-143  pca_g-144  \
# 0 -0.029888  0.684319 -0.316668  ...   0.735437  -0.033264  -0.025932
# 1  0.556428 -0.539718  0.831972  ...  -1.113827   0.952059   1.285865
# 2  0.363471 -0.003611  1.237966  ...   0.513153   1.179780   0.965568
# 3  0.305225 -0.191898 -1.389591  ...  -0.158321  -0.251697   1.203968
# 4 -0.212171 -1.067075  0.844018  ...  -1.322770  -0.215600  -0.859833
#
#      pca_c-0   pca_c-1   pca_c-2   pca_c-3   pca_c-4   pca_c-5   pca_c-6
# 0   4.883810  1.541913  1.541407  1.170438  0.913066 -1.064601 -0.229895
# 1   5.052956 -0.364877 -0.023767  1.002043 -0.532869  0.673775 -0.265609
# 2  -1.394569  0.297261  0.311774 -0.215324 -0.111797 -0.704118  0.870198
# 3 -10.982825  1.162351  0.965166 -1.574983  0.006538 -1.255822 -0.380491
# 4   3.601949  0.563094  0.661240 -0.286989  0.275704  0.276489  0.273743
#
# [5 rows x 1024 columns]
# cluster raw g/c (27796, 26) (3982, 26)
# cluster PCA g/c (27796, 5) (3982, 5)
# statistics features (27796, 180) (3982, 180)
# combine all FE results (27796, 1239) (3982, 1239)
# remove ctrl in train and test (25572, 1238) (3624, 1238)

# %%
# join processed features, scored_targets, non-scored_targets, drug_ids
train = x_train_fe.merge(train_targets_scored, on='sig_id')
train = train.merge(train_targets_nonscored, on='sig_id')
train = train.merge(train_drug, on='sig_id')
test = x_test_fe.copy()

# %%
# define target column set
target_cols = [x for x in train_targets_scored.columns if x != 'sig_id']
aux_target_cols = [x for x in train_targets_nonscored.columns if x != 'sig_id']
all_target_cols = target_cols + aux_target_cols

num_targets = len(target_cols)
num_aux_targets = len(aux_target_cols)
num_all_targets = len(all_target_cols)

print('num_targets: {}'.format(num_targets))
print('num_aux_targets: {}'.format(num_aux_targets))
print('num_all_targets: {}'.format(num_all_targets))
# Out:
# num_targets: 206
# num_aux_targets: 331
# num_all_targets: 537

# %%
print(train.shape)
print(test.shape)
print(sample_submission.shape)
# Out:
# (21948, 1776)
# (3624, 1238)
# (3982, 207)

# %% [markdown]
# # Dataset Classes

# %%
# dataset classes
# remarks: for saving mamories

class MoADataset:
    def __init__(self, features, targets):
        self.features = features
        self.targets = targets
        
    def __len__(self):
        return (self.features.shape[0])
    
    def __getitem__(self, idx):
        dct = {
            'x' : torch.tensor(self.features[idx, :], dtype=torch.float),
            'y' : torch.tensor(self.targets[idx, :], dtype=torch.float)
        }
        
        return dct
    
class TestDataset:
    def __init__(self, features):
        self.features = features
        
    def __len__(self):
        return (self.features.shape[0])
    
    def __getitem__(self, idx):
        dct = {
            'x' : torch.tensor(self.features[idx, :], dtype=torch.float)
        }

        return dct

# %%
# basic model train, validate, predict functions

def train_fn(model, optimizer, scheduler, loss_fn, dataloader, device):
    model.train()
    final_loss = 0
    
    for data in dataloader:
        optimizer.zero_grad()
        inputs, targets = data['x'].to(device), data['y'].to(device)
        outputs = model(inputs)
        loss = loss_fn(outputs, targets)
        loss.backward()
        optimizer.step()
        scheduler.step()

        final_loss += loss.item()
        
    final_loss /= len(dataloader)
    return final_loss

def valid_fn(model, loss_fn, dataloader, device):
    model.eval()
    final_loss = 0
    valid_preds = []
    
    for data in dataloader:
        inputs, targets = data['x'].to(device), data['y'].to(device)
        outputs = model(inputs)
        loss = loss_fn(outputs, targets)

        final_loss += loss.item()
        valid_preds.append(outputs.sigmoid().detach().cpu().numpy())
        
    final_loss /= len(dataloader)
    valid_preds = np.concatenate(valid_preds)
    return final_loss, valid_preds

# remarks: "inference" serves similar purpose as making prediction
def inference_fn(model, dataloader, device):
    model.eval()
    preds = []
    
    for data in dataloader:
        inputs = data['x'].to(device)

        with torch.no_grad():
            outputs = model(inputs)
        
        preds.append(outputs.sigmoid().detach().cpu().numpy())
        
    preds = np.concatenate(preds)
    return preds

# %%
# label smoothing as a regularization technique

class SmoothBCEwLogits(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.0):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets:torch.Tensor, n_labels:int, smoothing=0.0):
        assert 0 <= smoothing < 1

        with torch.no_grad():
            targets = targets * (1.0 - smoothing) + 0.5 * smoothing
            
        return targets

    def forward(self, inputs, targets):
        targets = SmoothBCEwLogits._smooth(targets, inputs.size(-1),
            self.smoothing)
        loss = F.binary_cross_entropy_with_logits(inputs, targets,self.weight)

        if  self.reduction == 'sum':
            loss = loss.sum()
        elif  self.reduction == 'mean':
            loss = loss.mean()

        return loss

# %% [markdown]
# # Model 1 - NN with 4 Hidden Layers

# %%
class Model(nn.Module):
    def __init__(self, num_features, num_targets):
        super(Model, self).__init__()
        self.hidden_size = [1500, 1250, 1000, 750]
        self.dropout_value = [0.5, 0.35, 0.3, 0.25]

        self.batch_norm1 = nn.BatchNorm1d(num_features)
        self.dense1 = nn.Linear(num_features, self.hidden_size[0])
        
        self.batch_norm2 = nn.BatchNorm1d(self.hidden_size[0])
        self.dropout2 = nn.Dropout(self.dropout_value[0])
        self.dense2 = nn.Linear(self.hidden_size[0], self.hidden_size[1])

        self.batch_norm3 = nn.BatchNorm1d(self.hidden_size[1])
        self.dropout3 = nn.Dropout(self.dropout_value[1])
        self.dense3 = nn.Linear(self.hidden_size[1], self.hidden_size[2])

        self.batch_norm4 = nn.BatchNorm1d(self.hidden_size[2])
        self.dropout4 = nn.Dropout(self.dropout_value[2])
        self.dense4 = nn.Linear(self.hidden_size[2], self.hidden_size[3])

        self.batch_norm5 = nn.BatchNorm1d(self.hidden_size[3])
        self.dropout5 = nn.Dropout(self.dropout_value[3])
        self.dense5 = nn.utils.weight_norm(nn.Linear(self.hidden_size[3], num_targets))
    
    def forward(self, x):
        x = self.batch_norm1(x)
        x = F.leaky_relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.leaky_relu(self.dense2(x))

        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x = F.leaky_relu(self.dense3(x))

        x = self.batch_norm4(x)
        x = self.dropout4(x)
        x = F.leaky_relu(self.dense4(x))

        x = self.batch_norm5(x)
        x = self.dropout5(x)
        x = self.dense5(x)
        return x

# remarks: this label smoothing class is never used later in the script
class LabelSmoothingLoss(nn.Module):
    def __init__(self, classes, smoothing=0.0, dim=-1):
        super(LabelSmoothingLoss, self).__init__()
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.cls = classes
        self.dim = dim

    def forward(self, pred, target):
        pred = pred.log_softmax(dim=self.dim)

        with torch.no_grad():
            true_dist = torch.zeros_like(pred)
            true_dist.fill_(self.smoothing / (self.cls - 1))
            true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
            
        return torch.mean(torch.sum(-true_dist * pred, dim=self.dim))

# %%
# class for Transfer Learning - create a new model by replacing last layer of the original model
# all parameters in old layers will be frozen

class FineTuneScheduler:
    def __init__(self, epochs):
        self.epochs = epochs
        self.epochs_per_step = 0
        self.frozen_layers = []

    def copy_without_top(self, model, num_features, num_targets, num_targets_new):
        self.frozen_layers = []

        model_new = Model(num_features, num_targets)
        model_new.load_state_dict(model.state_dict())

        # Freeze all weights
        for name, param in model_new.named_parameters():
            layer_index = name.split('.')[0][-1]

            if layer_index == 5:
                continue

            param.requires_grad = False

            # Save frozen layer names
            if layer_index not in self.frozen_layers:
                self.frozen_layers.append(layer_index)

        self.epochs_per_step = self.epochs // len(self.frozen_layers)

        # Replace the top layers with another ones
        model_new.batch_norm5 = nn.BatchNorm1d(model_new.hidden_size[3])
        model_new.dropout5 = nn.Dropout(model_new.dropout_value[3])
        model_new.dense5 = nn.utils.weight_norm(nn.Linear(model_new.hidden_size[-1], num_targets_new))
        model_new.to(DEVICE)
        return model_new

    def step(self, epoch, model):
        if len(self.frozen_layers) == 0:
            return

        if epoch % self.epochs_per_step == 0:
            last_frozen_index = self.frozen_layers[-1]
            
            # Unfreeze parameters of the last frozen layer
            for name, param in model.named_parameters():
                layer_index = name.split('.')[0][-1]

                if layer_index == last_frozen_index:
                    param.requires_grad = True

            del self.frozen_layers[-1]  # Remove the last layer as unfrozen

# %%
# function of basic One-Hot Encoding for cp featuers
def process_data(data):
    data = pd.get_dummies(data, columns=['cp_time','cp_dose'])
    return data

# %%
# define number of features input to NN
feature_cols = [c for c in process_data(train).columns if c not in all_target_cols]
feature_cols = [c for c in feature_cols if c not in ['kfold', 'sig_id', 'drug_id']]
num_features = len(feature_cols)
num_features
# Out:
# 1240

# %%
# HyperParameters

DEVICE = ('cuda' if torch.cuda.is_available() else 'cpu')
EPOCHS = 24
BATCH_SIZE = 128

WEIGHT_DECAY = {'ALL_TARGETS': 1e-5, 'SCORED_ONLY': 3e-6}
MAX_LR = {'ALL_TARGETS': 1e-2, 'SCORED_ONLY': 3e-3}
DIV_FACTOR = {'ALL_TARGETS': 1e3, 'SCORED_ONLY': 1e2}
PCT_START = 0.1

# %%
# Show model architecture
model = Model(num_features, num_all_targets)
model
# Out:
# Model(
#   (batch_norm1): BatchNorm1d(1240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dense1): Linear(in_features=1240, out_features=1500, bias=True)
#   (batch_norm2): BatchNorm1d(1500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (dense2): Linear(in_features=1500, out_features=1250, bias=True)
#   (batch_norm3): BatchNorm1d(1250, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout3): Dropout(p=0.35, inplace=False)
#   (dense3): Linear(in_features=1250, out_features=1000, bias=True)
#   (batch_norm4): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout4): Dropout(p=0.3, inplace=False)
#   (dense4): Linear(in_features=1000, out_features=750, bias=True)
#   (batch_norm5): BatchNorm1d(750, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout5): Dropout(p=0.25, inplace=False)
#   (dense5): Linear(in_features=750, out_features=537, bias=True)
# )

# %%
# stratified k-fold by drug_id

def make_cv_folds(train, SEEDS, NFOLDS, DRUG_THRESH):
    vc = train.drug_id.value_counts()
    vc1 = vc.loc[vc <= DRUG_THRESH].index.sort_values()
    vc2 = vc.loc[vc > DRUG_THRESH].index.sort_values()

    for seed_id in range(SEEDS):
        kfold_col = 'kfold_{}'.format(seed_id)
        
        # STRATIFY DRUGS 18X OR LESS
        dct1 = {}
        dct2 = {}

        skf = MultilabelStratifiedKFold(n_splits=NFOLDS, shuffle=True, random_state=seed_id)
        tmp = train.groupby('drug_id')[target_cols].mean().loc[vc1]

        for fold,(idxT, idxV) in enumerate(skf.split(tmp, tmp[target_cols])):
            dd = {k: fold for k in tmp.index[idxV].values}
            dct1.update(dd)

        # STRATIFY DRUGS MORE THAN 18X
        skf = MultilabelStratifiedKFold(n_splits=NFOLDS, shuffle=True, random_state=seed_id)
        tmp = train.loc[train.drug_id.isin(vc2)].reset_index(drop=True)

        for fold,(idxT, idxV) in enumerate(skf.split(tmp, tmp[target_cols])):
            dd = {k: fold for k in tmp.sig_id[idxV].values}
            dct2.update(dd)

        # ASSIGN FOLDS
        train[kfold_col] = train.drug_id.map(dct1)
        train.loc[train[kfold_col].isna(), kfold_col] = train.loc[train[kfold_col].isna(), 'sig_id'].map(dct2)
        train[kfold_col] = train[kfold_col].astype('int8')
        
    return train

SEEDS = 7
NFOLDS = 7
DRUG_THRESH = 18

train = make_cv_folds(train, SEEDS, NFOLDS, DRUG_THRESH)
train.head()
# Out:
#          sig_id  cp_dose  cp_time    rg_g-0    rg_g-1    rg_g-2    rg_g-3  \
# 0  id_000644bb2        0        0  1.146806  0.902075 -0.418339 -0.961202
# 1  id_000779bfc        0        2  0.128824  0.676862  0.274345  0.090495
# 2  id_000a6266a        0        1  0.790372  0.939951  1.428097 -0.121817
# 3  id_0015fd391        0        1 -0.729866 -0.277163 -0.441200  0.766612
# 4  id_001626bd3        1        2 -0.444558 -0.481202  0.974729  0.977467
#
#      rg_g-4    rg_g-5    rg_g-6  ...  xanthine_oxidase_inhibitor  \
# 0 -0.254770 -1.021300 -1.369236  ...                           0
# 1  1.208863  0.688965  0.316734  ...                           0
# 2 -0.002067  1.495091  0.238763  ...                           0
# 3  2.347817 -0.862761 -2.308829  ...                           0
# 4  1.468304 -0.874772 -0.372682  ...                           0
#
#    xiap_inhibitor    drug_id  kfold_0  kfold_1  kfold_2  kfold_3  kfold_4  \
# 0               0  b68db1d53        1        3        3        5        0
# 1               0  df89a8e5a        0        3        6        3        3
# 2               0  18bb41b2c        5        3        3        1        3
# 3               0  8c7f86626        4        3        1        2        4
# 4               0  7cbed3131        6        5        3        3        2
#
#    kfold_5  kfold_6
# 0        5        2
# 1        4        1
# 2        0        4
# 3        5        2
# 4        1        4
#
# [5 rows x 1783 columns]

# %%
# single-fold, single-seed training function

def run_training(fold_id, seed_id):
    seed_everything(seed_id)
    
    train_ = process_data(train)
    test_ = process_data(test)
    
    kfold_col = f'kfold_{seed_id}'
    trn_idx = train_[train_[kfold_col] != fold_id].index
    val_idx = train_[train_[kfold_col] == fold_id].index
    
    train_df = train_[train_[kfold_col] != fold_id].reset_index(drop=True)
    valid_df = train_[train_[kfold_col] == fold_id].reset_index(drop=True)
    
    def train_model(model, tag_name, target_cols_now, fine_tune_scheduler=None):
        x_train, y_train  = train_df[feature_cols].values, train_df[target_cols_now].values
        x_valid, y_valid =  valid_df[feature_cols].values, valid_df[target_cols_now].values
        
        train_dataset = MoADataset(x_train, y_train)
        valid_dataset = MoADataset(x_valid, y_valid)

        trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
        validloader = torch.utils.data.DataLoader(valid_dataset, batch_size=BATCH_SIZE, shuffle=False)
        
        optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=WEIGHT_DECAY[tag_name])
        scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer,
                                                  steps_per_epoch=len(trainloader),
                                                  pct_start=PCT_START,
                                                  div_factor=DIV_FACTOR[tag_name], 
                                                  max_lr=MAX_LR[tag_name],
                                                  epochs=EPOCHS)
        
        loss_fn = nn.BCEWithLogitsLoss()
        loss_tr = SmoothBCEwLogits(smoothing=0.001)

        oof = np.zeros((len(train), len(target_cols_now)))
        best_loss = np.inf
        
        for epoch in range(EPOCHS):
            if fine_tune_scheduler is not None:
                fine_tune_scheduler.step(epoch, model)

            train_loss = train_fn(model, optimizer, scheduler, loss_tr, trainloader, DEVICE)
            valid_loss, valid_preds = valid_fn(model, loss_fn, validloader, DEVICE)
            print(f"SEED: {seed_id}, FOLD: {fold_id}, {tag_name}, EPOCH: {epoch}, train_loss: {train_loss:.6f}, valid_loss: {valid_loss:.6f}")

            if np.isnan(valid_loss):
                break
            
            if valid_loss < best_loss:
                best_loss = valid_loss
                oof[val_idx] = valid_preds
                torch.save(model.state_dict(), f"NN_{tag_name}_SEED{seed_id}_FOLD{fold_id}_.pth") # modified to save best model per seed and fold

        return oof

    fine_tune_scheduler = FineTuneScheduler(EPOCHS)

    pretrained_model = Model(num_features, num_all_targets)
    pretrained_model.to(DEVICE)

    # Train on scored + nonscored targets
    train_model(pretrained_model, 'ALL_TARGETS', all_target_cols)

    # Load the pretrained model with the best loss
    pretrained_model = Model(num_features, num_all_targets)
    pretrained_model.load_state_dict(torch.load(f"NN_ALL_TARGETS_SEED{seed_id}_FOLD{fold_id}_.pth"))
    pretrained_model.to(DEVICE)

    # Copy model without the top layer
    final_model = fine_tune_scheduler.copy_without_top(pretrained_model, num_features, num_all_targets, num_targets)

    # Fine-tune the model on scored targets only
    oof = train_model(final_model, 'SCORED_ONLY', target_cols, fine_tune_scheduler)

    # Load the fine-tuned model with the best loss
    model = Model(num_features, num_targets)
    model.load_state_dict(torch.load(f"NN_SCORED_ONLY_SEED{seed_id}_FOLD{fold_id}_.pth"))
    model.to(DEVICE)

    #--------------------- PREDICTION---------------------
    x_test = test_[feature_cols].values
    testdataset = TestDataset(x_test)
    testloader = torch.utils.data.DataLoader(testdataset, batch_size=BATCH_SIZE, shuffle=False)
    
    predictions = np.zeros((len(test_), num_targets))
    predictions = inference_fn(model, testloader, DEVICE)
    return oof, predictions

# %%
# single-seed training function

def run_k_fold(NFOLDS, seed_id):
    oof = np.zeros((len(train), len(target_cols)))
    predictions = np.zeros((len(test), len(target_cols)))
    
    for fold_id in range(NFOLDS):
        oof_, pred_ = run_training(fold_id, seed_id)
        predictions += pred_ / NFOLDS
        oof += oof_
        
    return oof, predictions

# %%
# training on multiple SEEDS

SEED = [0, 1, 2, 3, 4, 5, 6]
oof = np.zeros((len(train), len(target_cols)))
predictions = np.zeros((len(test), len(target_cols)))

time_begin = time()

for seed_id in SEED:
    oof_, predictions_ = run_k_fold(NFOLDS, seed_id)
    oof += oof_ / len(SEED)
    predictions += predictions_ / len(SEED)

train[target_cols] = oof
test[target_cols] = predictions

# report total training time
time_diff = time() - time_begin
print(str(timedelta(seconds=time_diff)))
# Out:
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 0, train_loss: 0.495827, valid_loss: 0.019534
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 1, train_loss: 0.016943, valid_loss: 0.010596
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 2, train_loss: 0.014879, valid_loss: 0.010201
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 3, train_loss: 0.014007, valid_loss: 0.010136
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 4, train_loss: 0.014110, valid_loss: 0.010138
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 5, train_loss: 0.013947, valid_loss: 0.010213
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 6, train_loss: 0.013973, valid_loss: 0.010229
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 7, train_loss: 0.013985, valid_loss: 0.010278
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 8, train_loss: 0.013960, valid_loss: 0.010132
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 9, train_loss: 0.013926, valid_loss: 0.010111
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 10, train_loss: 0.013914, valid_loss: 0.010172
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 11, train_loss: 0.013871, valid_loss: 0.010143
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 12, train_loss: 0.013871, valid_loss: 0.010099
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 13, train_loss: 0.013824, valid_loss: 0.010039
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 14, train_loss: 0.013789, valid_loss: 0.010039
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 15, train_loss: 0.013744, valid_loss: 0.009947
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 16, train_loss: 0.013691, valid_loss: 0.009909
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 17, train_loss: 0.013583, valid_loss: 0.009886
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 18, train_loss: 0.013504, valid_loss: 0.009779
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 19, train_loss: 0.013374, valid_loss: 0.009737
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 20, train_loss: 0.013234, valid_loss: 0.009719
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 21, train_loss: 0.013115, valid_loss: 0.009662
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 22, train_loss: 0.012998, valid_loss: 0.009647
# SEED: 0, FOLD: 0, ALL_TARGETS, EPOCH: 23, train_loss: 0.012911, valid_loss: 0.009640
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 0, train_loss: 0.641390, valid_loss: 0.259110
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 1, train_loss: 0.058633, valid_loss: 0.019236
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 2, train_loss: 0.020910, valid_loss: 0.016940
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 3, train_loss: 0.019815, valid_loss: 0.016648
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 4, train_loss: 0.022439, valid_loss: 0.016452
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 5, train_loss: 0.019562, valid_loss: 0.016545
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 6, train_loss: 0.019356, valid_loss: 0.016403
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 7, train_loss: 0.019295, valid_loss: 0.016351
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 8, train_loss: 0.019619, valid_loss: 0.016444
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 9, train_loss: 0.019365, valid_loss: 0.017097
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 10, train_loss: 0.019260, valid_loss: 0.016409
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 11, train_loss: 0.019142, valid_loss: 0.016427
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 12, train_loss: 0.019443, valid_loss: 0.016406
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 13, train_loss: 0.019134, valid_loss: 0.016359
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 14, train_loss: 0.018942, valid_loss: 0.016334
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 15, train_loss: 0.018747, valid_loss: 0.016439
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 16, train_loss: 0.019216, valid_loss: 0.016383
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 17, train_loss: 0.018680, valid_loss: 0.016280
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 18, train_loss: 0.018324, valid_loss: 0.016266
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 19, train_loss: 0.017977, valid_loss: 0.016313
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 20, train_loss: 0.017633, valid_loss: 0.016328
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 21, train_loss: 0.017353, valid_loss: 0.016360
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 22, train_loss: 0.017125, valid_loss: 0.016363
# SEED: 0, FOLD: 0, SCORED_ONLY, EPOCH: 23, train_loss: 0.017077, valid_loss: 0.016387
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 0, train_loss: 0.498263, valid_loss: 0.024126
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 1, train_loss: 0.016791, valid_loss: 0.011678
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 2, train_loss: 0.014436, valid_loss: 0.011058
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 3, train_loss: 0.014029, valid_loss: 0.010843
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 4, train_loss: 0.013887, valid_loss: 0.010846
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 5, train_loss: 0.013892, valid_loss: 0.011048
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 6, train_loss: 0.013897, valid_loss: 0.010885
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 7, train_loss: 0.013898, valid_loss: 0.010936
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 8, train_loss: 0.013901, valid_loss: 0.010972
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 9, train_loss: 0.013836, valid_loss: 0.010810
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 10, train_loss: 0.013813, valid_loss: 0.010898
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 11, train_loss: 0.013788, valid_loss: 0.010788
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 12, train_loss: 0.013761, valid_loss: 0.010841
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 13, train_loss: 0.013742, valid_loss: 0.010661
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 14, train_loss: 0.013731, valid_loss: 0.010654
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 15, train_loss: 0.013657, valid_loss: 0.010675
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 16, train_loss: 0.013585, valid_loss: 0.010614
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 17, train_loss: 0.013514, valid_loss: 0.010585
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 18, train_loss: 0.013376, valid_loss: 0.010431
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 19, train_loss: 0.013291, valid_loss: 0.010436
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 20, train_loss: 0.013177, valid_loss: 0.010322
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 21, train_loss: 0.013031, valid_loss: 0.010309
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 22, train_loss: 0.012911, valid_loss: 0.010277
# SEED: 0, FOLD: 1, ALL_TARGETS, EPOCH: 23, train_loss: 0.012852, valid_loss: 0.010281
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 0, train_loss: 0.642113, valid_loss: 0.262581
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 1, train_loss: 0.059314, valid_loss: 0.019923
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 2, train_loss: 0.020908, valid_loss: 0.017582
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 3, train_loss: 0.019850, valid_loss: 0.017229
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 4, train_loss: 0.022075, valid_loss: 0.016952
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 5, train_loss: 0.019705, valid_loss: 0.016970
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 6, train_loss: 0.019520, valid_loss: 0.016814
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 7, train_loss: 0.019354, valid_loss: 0.016846
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 8, train_loss: 0.019588, valid_loss: 0.017008
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 9, train_loss: 0.019432, valid_loss: 0.016799
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 10, train_loss: 0.019305, valid_loss: 0.017023
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 11, train_loss: 0.019148, valid_loss: 0.017009
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 12, train_loss: 0.019411, valid_loss: 0.016887
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 13, train_loss: 0.019171, valid_loss: 0.016960
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 14, train_loss: 0.018972, valid_loss: 0.016831
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 15, train_loss: 0.018836, valid_loss: 0.016887
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 16, train_loss: 0.019199, valid_loss: 0.016843
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 17, train_loss: 0.018751, valid_loss: 0.016893
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 18, train_loss: 0.018380, valid_loss: 0.016811
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 19, train_loss: 0.018026, valid_loss: 0.016819
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 20, train_loss: 0.017702, valid_loss: 0.016891
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 21, train_loss: 0.017456, valid_loss: 0.016871
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 22, train_loss: 0.017237, valid_loss: 0.016896
# SEED: 0, FOLD: 1, SCORED_ONLY, EPOCH: 23, train_loss: 0.017163, valid_loss: 0.016921
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 0, train_loss: 0.496089, valid_loss: 0.020394
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 1, train_loss: 0.016398, valid_loss: 0.011773
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 2, train_loss: 0.014319, valid_loss: 0.011054
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 3, train_loss: 0.014010, valid_loss: 0.012615
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 4, train_loss: 0.013975, valid_loss: 0.011126
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 5, train_loss: 0.013896, valid_loss: 0.010864
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 6, train_loss: 0.013836, valid_loss: 0.010826
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 7, train_loss: 0.013864, valid_loss: 0.010859
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 8, train_loss: 0.013830, valid_loss: 0.011029
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 9, train_loss: 0.013834, valid_loss: 0.011475
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 10, train_loss: 0.013803, valid_loss: 0.010780
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 11, train_loss: 0.013763, valid_loss: 0.010867
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 12, train_loss: 0.013762, valid_loss: 0.010930
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 13, train_loss: 0.013717, valid_loss: 0.010827
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 14, train_loss: 0.013683, valid_loss: 0.010702
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 15, train_loss: 0.013633, valid_loss: 0.010684
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 16, train_loss: 0.013562, valid_loss: 0.010617
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 17, train_loss: 0.013490, valid_loss: 0.010511
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 18, train_loss: 0.013381, valid_loss: 0.010526
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 19, train_loss: 0.013258, valid_loss: 0.010425
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 20, train_loss: 0.013113, valid_loss: 0.010399
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 21, train_loss: 0.012990, valid_loss: 0.010334
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 22, train_loss: 0.012871, valid_loss: 0.010362
# SEED: 0, FOLD: 2, ALL_TARGETS, EPOCH: 23, train_loss: 0.012817, valid_loss: 0.010336
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 0, train_loss: 0.638305, valid_loss: 0.263049
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 1, train_loss: 0.058920, valid_loss: 0.019984
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 2, train_loss: 0.020777, valid_loss: 0.017901
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 3, train_loss: 0.019760, valid_loss: 0.017720
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 4, train_loss: 0.021960, valid_loss: 0.017355
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 5, train_loss: 0.019572, valid_loss: 0.017316
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 6, train_loss: 0.019405, valid_loss: 0.017374
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 7, train_loss: 0.019307, valid_loss: 0.017594
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 8, train_loss: 0.019742, valid_loss: 0.017439
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 9, train_loss: 0.019401, valid_loss: 0.017604
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 10, train_loss: 0.019213, valid_loss: 0.017515
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 11, train_loss: 0.019071, valid_loss: 0.017695
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 12, train_loss: 0.019399, valid_loss: 0.017401
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 13, train_loss: 0.019115, valid_loss: 0.017401
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 14, train_loss: 0.018938, valid_loss: 0.017365
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 15, train_loss: 0.018835, valid_loss: 0.017526
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 16, train_loss: 0.019098, valid_loss: 0.017554
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 17, train_loss: 0.018709, valid_loss: 0.017548
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 18, train_loss: 0.018298, valid_loss: 0.017417
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 19, train_loss: 0.017929, valid_loss: 0.017473
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 20, train_loss: 0.017587, valid_loss: 0.017540
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 21, train_loss: 0.017337, valid_loss: 0.017575
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 22, train_loss: 0.017097, valid_loss: 0.017545
# SEED: 0, FOLD: 2, SCORED_ONLY, EPOCH: 23, train_loss: 0.017043, valid_loss: 0.017582
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 0, train_loss: 0.496938, valid_loss: 0.023219
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 1, train_loss: 0.016813, valid_loss: 0.012216
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 2, train_loss: 0.014655, valid_loss: 0.011219
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 3, train_loss: 0.014008, valid_loss: 0.011074
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 4, train_loss: 0.013904, valid_loss: 0.011125
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 5, train_loss: 0.013825, valid_loss: 0.011090
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 6, train_loss: 0.014122, valid_loss: 0.011171
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 7, train_loss: 0.013885, valid_loss: 0.011196
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 8, train_loss: 0.013855, valid_loss: 0.011196
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 9, train_loss: 0.013851, valid_loss: 0.010946
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 10, train_loss: 0.013831, valid_loss: 0.010854
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 11, train_loss: 0.013774, valid_loss: 0.011009
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 12, train_loss: 0.013760, valid_loss: 0.010918
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 13, train_loss: 0.013713, valid_loss: 0.010959
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 14, train_loss: 0.013684, valid_loss: 0.010970
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 15, train_loss: 0.013588, valid_loss: 0.010861
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 16, train_loss: 0.013557, valid_loss: 0.010895
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 17, train_loss: 0.013477, valid_loss: 0.010745
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 18, train_loss: 0.013374, valid_loss: 0.010684
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 19, train_loss: 0.013230, valid_loss: 0.010636
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 20, train_loss: 0.013128, valid_loss: 0.010589
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 21, train_loss: 0.013003, valid_loss: 0.010503
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 22, train_loss: 0.012888, valid_loss: 0.010495
# SEED: 0, FOLD: 3, ALL_TARGETS, EPOCH: 23, train_loss: 0.012817, valid_loss: 0.010483
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 0, train_loss: 0.642323, valid_loss: 0.258172
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 1, train_loss: 0.058464, valid_loss: 0.020738
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 2, train_loss: 0.020687, valid_loss: 0.018409
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 3, train_loss: 0.019641, valid_loss: 0.018171
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 4, train_loss: 0.022270, valid_loss: 0.018182
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 5, train_loss: 0.019471, valid_loss: 0.017955
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 6, train_loss: 0.019579, valid_loss: 0.018152
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 7, train_loss: 0.019216, valid_loss: 0.018084
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 8, train_loss: 0.019378, valid_loss: 0.018316
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 9, train_loss: 0.019244, valid_loss: 0.018066
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 10, train_loss: 0.019086, valid_loss: 0.017985
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 11, train_loss: 0.018956, valid_loss: 0.018102
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 12, train_loss: 0.019268, valid_loss: 0.018186
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 13, train_loss: 0.018950, valid_loss: 0.018161
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 14, train_loss: 0.018812, valid_loss: 0.018137
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 15, train_loss: 0.018677, valid_loss: 0.018123
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 16, train_loss: 0.018983, valid_loss: 0.018159
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 17, train_loss: 0.018598, valid_loss: 0.018114
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 18, train_loss: 0.018250, valid_loss: 0.018034
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 19, train_loss: 0.017866, valid_loss: 0.018034
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 20, train_loss: 0.017560, valid_loss: 0.018090
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 21, train_loss: 0.017279, valid_loss: 0.018107
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 22, train_loss: 0.017093, valid_loss: 0.018140
# SEED: 0, FOLD: 3, SCORED_ONLY, EPOCH: 23, train_loss: 0.016985, valid_loss: 0.018107
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 0, train_loss: 0.498646, valid_loss: 0.024412
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 1, train_loss: 0.016792, valid_loss: 0.011333
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 2, train_loss: 0.014392, valid_loss: 0.010737
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 3, train_loss: 0.014011, valid_loss: 0.010779
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 4, train_loss: 0.013999, valid_loss: 0.010567
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 5, train_loss: 0.013893, valid_loss: 0.010535
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 6, train_loss: 0.013923, valid_loss: 0.010493
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 7, train_loss: 0.013881, valid_loss: 0.010667
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 8, train_loss: 0.013854, valid_loss: 0.010843
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 9, train_loss: 0.013864, valid_loss: 0.010664
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 10, train_loss: 0.013855, valid_loss: 0.010605
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 11, train_loss: 0.013848, valid_loss: 0.010568
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 12, train_loss: 0.013786, valid_loss: 0.010346
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 13, train_loss: 0.013755, valid_loss: 0.010471
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 14, train_loss: 0.013728, valid_loss: 0.010337
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 15, train_loss: 0.013655, valid_loss: 0.010323
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 16, train_loss: 0.013600, valid_loss: 0.010324
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 17, train_loss: 0.013487, valid_loss: 0.010277
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 18, train_loss: 0.013415, valid_loss: 0.010168
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 19, train_loss: 0.013268, valid_loss: 0.010128
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 20, train_loss: 0.013139, valid_loss: 0.010049
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 21, train_loss: 0.012983, valid_loss: 0.010005
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 22, train_loss: 0.012857, valid_loss: 0.009993
# SEED: 0, FOLD: 4, ALL_TARGETS, EPOCH: 23, train_loss: 0.012780, valid_loss: 0.010007
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 0, train_loss: 0.642923, valid_loss: 0.266283
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 1, train_loss: 0.059433, valid_loss: 0.019920
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 2, train_loss: 0.020612, valid_loss: 0.017582
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 3, train_loss: 0.019560, valid_loss: 0.017300
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 4, train_loss: 0.022100, valid_loss: 0.017214
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 5, train_loss: 0.019341, valid_loss: 0.017027
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 6, train_loss: 0.019148, valid_loss: 0.016972
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 7, train_loss: 0.019085, valid_loss: 0.017036
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 8, train_loss: 0.019344, valid_loss: 0.017078
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 9, train_loss: 0.019056, valid_loss: 0.017317
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 10, train_loss: 0.018984, valid_loss: 0.017115
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 11, train_loss: 0.018848, valid_loss: 0.017063
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 12, train_loss: 0.019136, valid_loss: 0.016992
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 13, train_loss: 0.018804, valid_loss: 0.017034
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 14, train_loss: 0.018681, valid_loss: 0.017067
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 15, train_loss: 0.018508, valid_loss: 0.016977
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 16, train_loss: 0.018926, valid_loss: 0.016979
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 17, train_loss: 0.018474, valid_loss: 0.016998
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 18, train_loss: 0.018078, valid_loss: 0.016945
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 19, train_loss: 0.017662, valid_loss: 0.017032
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 20, train_loss: 0.017327, valid_loss: 0.017075
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 21, train_loss: 0.016960, valid_loss: 0.017100
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 22, train_loss: 0.016753, valid_loss: 0.017089
# SEED: 0, FOLD: 4, SCORED_ONLY, EPOCH: 23, train_loss: 0.016706, valid_loss: 0.017083
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 0, train_loss: 0.497116, valid_loss: 0.023770
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 1, train_loss: 0.016772, valid_loss: 0.011527
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 2, train_loss: 0.014573, valid_loss: 0.010919
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 3, train_loss: 0.014049, valid_loss: 0.010874
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 4, train_loss: 0.013948, valid_loss: 0.010829
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 5, train_loss: 0.013928, valid_loss: 0.010728
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 6, train_loss: 0.013928, valid_loss: 0.010855
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 7, train_loss: 0.013934, valid_loss: 0.010774
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 8, train_loss: 0.013913, valid_loss: 0.010819
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 9, train_loss: 0.013845, valid_loss: 0.010742
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 10, train_loss: 0.013842, valid_loss: 0.010679
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 11, train_loss: 0.013839, valid_loss: 0.010660
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 12, train_loss: 0.013801, valid_loss: 0.010627
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 13, train_loss: 0.013773, valid_loss: 0.010643
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 14, train_loss: 0.013692, valid_loss: 0.010807
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 15, train_loss: 0.013676, valid_loss: 0.010643
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 16, train_loss: 0.013589, valid_loss: 0.010484
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 17, train_loss: 0.013499, valid_loss: 0.010516
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 18, train_loss: 0.013401, valid_loss: 0.010409
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 19, train_loss: 0.013283, valid_loss: 0.010309
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 20, train_loss: 0.013156, valid_loss: 0.010295
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 21, train_loss: 0.013033, valid_loss: 0.010207
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 22, train_loss: 0.012908, valid_loss: 0.010201
# SEED: 0, FOLD: 5, ALL_TARGETS, EPOCH: 23, train_loss: 0.012839, valid_loss: 0.010205
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 0, train_loss: 0.643903, valid_loss: 0.264585
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 1, train_loss: 0.059284, valid_loss: 0.020397
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 2, train_loss: 0.020726, valid_loss: 0.018260
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 3, train_loss: 0.019620, valid_loss: 0.017927
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 4, train_loss: 0.022209, valid_loss: 0.017756
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 5, train_loss: 0.019490, valid_loss: 0.017869
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 6, train_loss: 0.019360, valid_loss: 0.017735
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 7, train_loss: 0.019210, valid_loss: 0.017772
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 8, train_loss: 0.019425, valid_loss: 0.017843
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 9, train_loss: 0.019208, valid_loss: 0.017697
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 10, train_loss: 0.019177, valid_loss: 0.017867
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 11, train_loss: 0.019026, valid_loss: 0.017696
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 12, train_loss: 0.019284, valid_loss: 0.017654
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 13, train_loss: 0.019017, valid_loss: 0.017735
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 14, train_loss: 0.018768, valid_loss: 0.017719
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 15, train_loss: 0.018619, valid_loss: 0.017669
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 16, train_loss: 0.018986, valid_loss: 0.017785
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 17, train_loss: 0.018584, valid_loss: 0.017791
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 18, train_loss: 0.018172, valid_loss: 0.017755
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 19, train_loss: 0.017823, valid_loss: 0.017665
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 20, train_loss: 0.017456, valid_loss: 0.017752
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 21, train_loss: 0.017182, valid_loss: 0.017755
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 22, train_loss: 0.016984, valid_loss: 0.017791
# SEED: 0, FOLD: 5, SCORED_ONLY, EPOCH: 23, train_loss: 0.016887, valid_loss: 0.017768
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 0, train_loss: 0.497968, valid_loss: 0.022236
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 1, train_loss: 0.016741, valid_loss: 0.014098
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 2, train_loss: 0.014713, valid_loss: 0.016300
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 3, train_loss: 0.014181, valid_loss: 0.011006
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 4, train_loss: 0.013860, valid_loss: 0.011324
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 5, train_loss: 0.013882, valid_loss: 0.011888
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 6, train_loss: 0.013858, valid_loss: 0.010947
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 7, train_loss: 0.013822, valid_loss: 0.011105
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 8, train_loss: 0.013851, valid_loss: 0.011254
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 9, train_loss: 0.013832, valid_loss: 0.011071
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 10, train_loss: 0.013806, valid_loss: 0.010887
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 11, train_loss: 0.013773, valid_loss: 0.010852
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 12, train_loss: 0.013758, valid_loss: 0.010765
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 13, train_loss: 0.013739, valid_loss: 0.010864
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 14, train_loss: 0.013677, valid_loss: 0.010773
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 15, train_loss: 0.013620, valid_loss: 0.010765
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 16, train_loss: 0.013560, valid_loss: 0.010738
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 17, train_loss: 0.013459, valid_loss: 0.010626
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 18, train_loss: 0.013353, valid_loss: 0.010570
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 19, train_loss: 0.013248, valid_loss: 0.010549
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 20, train_loss: 0.013117, valid_loss: 0.010436
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 21, train_loss: 0.012975, valid_loss: 0.010392
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 22, train_loss: 0.012865, valid_loss: 0.010381
# SEED: 0, FOLD: 6, ALL_TARGETS, EPOCH: 23, train_loss: 0.012794, valid_loss: 0.010380
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 0, train_loss: 0.644641, valid_loss: 0.259860
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 1, train_loss: 0.058760, valid_loss: 0.020264
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 2, train_loss: 0.020730, valid_loss: 0.018091
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 3, train_loss: 0.019697, valid_loss: 0.017767
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 4, train_loss: 0.022240, valid_loss: 0.017843
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 5, train_loss: 0.019452, valid_loss: 0.017782
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 6, train_loss: 0.019288, valid_loss: 0.017704
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 7, train_loss: 0.019181, valid_loss: 0.017777
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 8, train_loss: 0.019375, valid_loss: 0.017638
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 9, train_loss: 0.019127, valid_loss: 0.017603
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 10, train_loss: 0.018992, valid_loss: 0.017815
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 11, train_loss: 0.018940, valid_loss: 0.017640
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 12, train_loss: 0.019205, valid_loss: 0.017584
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 13, train_loss: 0.018930, valid_loss: 0.017522
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 14, train_loss: 0.018678, valid_loss: 0.017522
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 15, train_loss: 0.018582, valid_loss: 0.017671
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 16, train_loss: 0.018942, valid_loss: 0.017726
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 17, train_loss: 0.018494, valid_loss: 0.017520
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 18, train_loss: 0.018148, valid_loss: 0.017563
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 19, train_loss: 0.017774, valid_loss: 0.017562
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 20, train_loss: 0.017467, valid_loss: 0.017540
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 21, train_loss: 0.017192, valid_loss: 0.017557
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 22, train_loss: 0.017027, valid_loss: 0.017592
# SEED: 0, FOLD: 6, SCORED_ONLY, EPOCH: 23, train_loss: 0.016960, valid_loss: 0.017609
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 0, train_loss: 0.496907, valid_loss: 0.022220
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 1, train_loss: 0.016691, valid_loss: 0.011721
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 2, train_loss: 0.014363, valid_loss: 0.011189
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 3, train_loss: 0.014141, valid_loss: 0.011181
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 4, train_loss: 0.013894, valid_loss: 0.011085
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 5, train_loss: 0.014159, valid_loss: 0.012620
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 6, train_loss: 0.013991, valid_loss: 0.011047
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 7, train_loss: 0.013886, valid_loss: 0.011054
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 8, train_loss: 0.013847, valid_loss: 0.011154
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 9, train_loss: 0.013864, valid_loss: 0.011021
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 10, train_loss: 0.013806, valid_loss: 0.011231
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 11, train_loss: 0.013810, valid_loss: 0.010971
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 12, train_loss: 0.013766, valid_loss: 0.010991
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 13, train_loss: 0.013724, valid_loss: 0.010876
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 14, train_loss: 0.013695, valid_loss: 0.010864
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 15, train_loss: 0.013624, valid_loss: 0.010789
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 16, train_loss: 0.013577, valid_loss: 0.010681
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 17, train_loss: 0.013495, valid_loss: 0.010679
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 18, train_loss: 0.013406, valid_loss: 0.010669
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 19, train_loss: 0.013288, valid_loss: 0.010581
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 20, train_loss: 0.013158, valid_loss: 0.010552
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 21, train_loss: 0.013031, valid_loss: 0.010457
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 22, train_loss: 0.012903, valid_loss: 0.010423
# SEED: 1, FOLD: 0, ALL_TARGETS, EPOCH: 23, train_loss: 0.012852, valid_loss: 0.010425
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 0, train_loss: 0.645572, valid_loss: 0.264242
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 1, train_loss: 0.059102, valid_loss: 0.020115
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 2, train_loss: 0.020957, valid_loss: 0.017852
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 3, train_loss: 0.019842, valid_loss: 0.017366
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 4, train_loss: 0.024863, valid_loss: 0.017193
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 5, train_loss: 0.019573, valid_loss: 0.017127
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 6, train_loss: 0.019411, valid_loss: 0.017182
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 7, train_loss: 0.019290, valid_loss: 0.017252
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 8, train_loss: 0.019532, valid_loss: 0.017207
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 9, train_loss: 0.019309, valid_loss: 0.017219
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 10, train_loss: 0.019229, valid_loss: 0.017265
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 11, train_loss: 0.019106, valid_loss: 0.017219
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 12, train_loss: 0.019417, valid_loss: 0.017179
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 13, train_loss: 0.019179, valid_loss: 0.017168
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 14, train_loss: 0.018973, valid_loss: 0.017226
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 15, train_loss: 0.018804, valid_loss: 0.017096
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 16, train_loss: 0.019232, valid_loss: 0.017172
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 17, train_loss: 0.018771, valid_loss: 0.017156
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 18, train_loss: 0.018407, valid_loss: 0.017161
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 19, train_loss: 0.018043, valid_loss: 0.017100
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 20, train_loss: 0.017725, valid_loss: 0.017100
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 21, train_loss: 0.017452, valid_loss: 0.017053
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 22, train_loss: 0.017241, valid_loss: 0.017066
# SEED: 1, FOLD: 0, SCORED_ONLY, EPOCH: 23, train_loss: 0.017153, valid_loss: 0.017051
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 0, train_loss: 0.495958, valid_loss: 0.024468
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 1, train_loss: 0.016897, valid_loss: 0.011738
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 2, train_loss: 0.014631, valid_loss: 0.011531
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 3, train_loss: 0.014113, valid_loss: 0.010664
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 4, train_loss: 0.014052, valid_loss: 0.010543
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 5, train_loss: 0.014012, valid_loss: 0.011081
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 6, train_loss: 0.013977, valid_loss: 0.010827
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 7, train_loss: 0.013995, valid_loss: 0.010600
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 8, train_loss: 0.013921, valid_loss: 0.010632
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 9, train_loss: 0.013924, valid_loss: 0.010661
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 10, train_loss: 0.013883, valid_loss: 0.010512
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 11, train_loss: 0.013843, valid_loss: 0.010530
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 12, train_loss: 0.013840, valid_loss: 0.010461
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 13, train_loss: 0.013799, valid_loss: 0.010536
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 14, train_loss: 0.013772, valid_loss: 0.010356
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 15, train_loss: 0.013687, valid_loss: 0.010470
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 16, train_loss: 0.013632, valid_loss: 0.010348
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 17, train_loss: 0.013562, valid_loss: 0.010256
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 18, train_loss: 0.013454, valid_loss: 0.010191
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 19, train_loss: 0.013359, valid_loss: 0.010112
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 20, train_loss: 0.013199, valid_loss: 0.010067
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 21, train_loss: 0.013080, valid_loss: 0.010021
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 22, train_loss: 0.012953, valid_loss: 0.010007
# SEED: 1, FOLD: 1, ALL_TARGETS, EPOCH: 23, train_loss: 0.012888, valid_loss: 0.010005
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 0, train_loss: 0.643652, valid_loss: 0.260981
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 1, train_loss: 0.058143, valid_loss: 0.020067
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 2, train_loss: 0.020860, valid_loss: 0.017759
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 3, train_loss: 0.019761, valid_loss: 0.017625
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 4, train_loss: 0.021672, valid_loss: 0.017640
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 5, train_loss: 0.019464, valid_loss: 0.017462
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 6, train_loss: 0.019331, valid_loss: 0.017426
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 7, train_loss: 0.019282, valid_loss: 0.017519
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 8, train_loss: 0.019507, valid_loss: 0.017635
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 9, train_loss: 0.019286, valid_loss: 0.017462
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 10, train_loss: 0.019160, valid_loss: 0.017436
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 11, train_loss: 0.019039, valid_loss: 0.017486
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 12, train_loss: 0.019326, valid_loss: 0.017418
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 13, train_loss: 0.019043, valid_loss: 0.017363
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 14, train_loss: 0.018868, valid_loss: 0.017392
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 15, train_loss: 0.018740, valid_loss: 0.017388
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 16, train_loss: 0.019067, valid_loss: 0.017403
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 17, train_loss: 0.018679, valid_loss: 0.017360
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 18, train_loss: 0.018316, valid_loss: 0.017384
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 19, train_loss: 0.017922, valid_loss: 0.017433
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 20, train_loss: 0.017591, valid_loss: 0.017466
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 21, train_loss: 0.017327, valid_loss: 0.017438
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 22, train_loss: 0.017165, valid_loss: 0.017428
# SEED: 1, FOLD: 1, SCORED_ONLY, EPOCH: 23, train_loss: 0.017088, valid_loss: 0.017434
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 0, train_loss: 0.497842, valid_loss: 0.022095
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 1, train_loss: 0.016626, valid_loss: 0.011710
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 2, train_loss: 0.014820, valid_loss: 0.010838
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 3, train_loss: 0.013985, valid_loss: 0.010810
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 4, train_loss: 0.013845, valid_loss: 0.010758
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 5, train_loss: 0.013884, valid_loss: 0.010767
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 6, train_loss: 0.013845, valid_loss: 0.010752
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 7, train_loss: 0.013885, valid_loss: 0.010848
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 8, train_loss: 0.013898, valid_loss: 0.010922
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 9, train_loss: 0.013834, valid_loss: 0.010692
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 10, train_loss: 0.013817, valid_loss: 0.010690
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 11, train_loss: 0.013800, valid_loss: 0.010730
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 12, train_loss: 0.013787, valid_loss: 0.010831
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 13, train_loss: 0.013768, valid_loss: 0.010777
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 14, train_loss: 0.013700, valid_loss: 0.010603
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 15, train_loss: 0.013639, valid_loss: 0.010575
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 16, train_loss: 0.013588, valid_loss: 0.010526
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 17, train_loss: 0.013522, valid_loss: 0.010432
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 18, train_loss: 0.013402, valid_loss: 0.010440
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 19, train_loss: 0.013300, valid_loss: 0.010421
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 20, train_loss: 0.013156, valid_loss: 0.010347
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 21, train_loss: 0.013036, valid_loss: 0.010285
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 22, train_loss: 0.012924, valid_loss: 0.010235
# SEED: 1, FOLD: 2, ALL_TARGETS, EPOCH: 23, train_loss: 0.012860, valid_loss: 0.010232
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 0, train_loss: 0.643556, valid_loss: 0.262229
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 1, train_loss: 0.059155, valid_loss: 0.020343
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 2, train_loss: 0.020834, valid_loss: 0.018161
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 3, train_loss: 0.019800, valid_loss: 0.017884
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 4, train_loss: 0.022520, valid_loss: 0.017845
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 5, train_loss: 0.019567, valid_loss: 0.017824
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 6, train_loss: 0.019373, valid_loss: 0.017852
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 7, train_loss: 0.019252, valid_loss: 0.017614
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 8, train_loss: 0.019515, valid_loss: 0.017885
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 9, train_loss: 0.019283, valid_loss: 0.017909
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 10, train_loss: 0.019171, valid_loss: 0.017807
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 11, train_loss: 0.019096, valid_loss: 0.017794
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 12, train_loss: 0.019319, valid_loss: 0.017667
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 13, train_loss: 0.019038, valid_loss: 0.017796
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 14, train_loss: 0.018853, valid_loss: 0.017682
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 15, train_loss: 0.018726, valid_loss: 0.017759
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 16, train_loss: 0.019112, valid_loss: 0.017733
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 17, train_loss: 0.018611, valid_loss: 0.017745
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 18, train_loss: 0.018198, valid_loss: 0.017634
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 19, train_loss: 0.017819, valid_loss: 0.017681
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 20, train_loss: 0.017523, valid_loss: 0.017752
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 21, train_loss: 0.017228, valid_loss: 0.017759
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 22, train_loss: 0.017056, valid_loss: 0.017725
# SEED: 1, FOLD: 2, SCORED_ONLY, EPOCH: 23, train_loss: 0.016992, valid_loss: 0.017772
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 0, train_loss: 0.496136, valid_loss: 0.021732
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 1, train_loss: 0.016714, valid_loss: 0.011349
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 2, train_loss: 0.014559, valid_loss: 0.010727
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 3, train_loss: 0.014050, valid_loss: 0.010689
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 4, train_loss: 0.013975, valid_loss: 0.010574
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 5, train_loss: 0.013956, valid_loss: 0.010846
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 6, train_loss: 0.013945, valid_loss: 0.010903
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 7, train_loss: 0.013902, valid_loss: 0.010676
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 8, train_loss: 0.013891, valid_loss: 0.010732
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 9, train_loss: 0.013858, valid_loss: 0.010686
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 10, train_loss: 0.013852, valid_loss: 0.010560
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 11, train_loss: 0.013856, valid_loss: 0.010582
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 12, train_loss: 0.013823, valid_loss: 0.010553
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 13, train_loss: 0.013782, valid_loss: 0.010594
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 14, train_loss: 0.013781, valid_loss: 0.010490
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 15, train_loss: 0.013677, valid_loss: 0.010462
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 16, train_loss: 0.013631, valid_loss: 0.010401
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 17, train_loss: 0.013550, valid_loss: 0.010397
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 18, train_loss: 0.013455, valid_loss: 0.010304
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 19, train_loss: 0.013320, valid_loss: 0.010184
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 20, train_loss: 0.013180, valid_loss: 0.010160
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 21, train_loss: 0.013066, valid_loss: 0.010127
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 22, train_loss: 0.012946, valid_loss: 0.010098
# SEED: 1, FOLD: 3, ALL_TARGETS, EPOCH: 23, train_loss: 0.012884, valid_loss: 0.010107
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 0, train_loss: 0.640566, valid_loss: 0.263927
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 1, train_loss: 0.059180, valid_loss: 0.020001
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 2, train_loss: 0.020757, valid_loss: 0.017812
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 3, train_loss: 0.019817, valid_loss: 0.017507
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 4, train_loss: 0.021638, valid_loss: 0.017387
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 5, train_loss: 0.019544, valid_loss: 0.017535
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 6, train_loss: 0.019395, valid_loss: 0.017488
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 7, train_loss: 0.019319, valid_loss: 0.017387
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 8, train_loss: 0.019572, valid_loss: 0.017726
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 9, train_loss: 0.019364, valid_loss: 0.017346
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 10, train_loss: 0.019179, valid_loss: 0.017425
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 11, train_loss: 0.019102, valid_loss: 0.017448
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 12, train_loss: 0.019366, valid_loss: 0.017229
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 13, train_loss: 0.019110, valid_loss: 0.017279
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 14, train_loss: 0.018944, valid_loss: 0.017338
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 15, train_loss: 0.018791, valid_loss: 0.017378
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 16, train_loss: 0.019110, valid_loss: 0.017433
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 17, train_loss: 0.018685, valid_loss: 0.017335
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 18, train_loss: 0.018336, valid_loss: 0.017384
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 19, train_loss: 0.017973, valid_loss: 0.017362
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 20, train_loss: 0.017608, valid_loss: 0.017444
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 21, train_loss: 0.017370, valid_loss: 0.017437
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 22, train_loss: 0.017157, valid_loss: 0.017450
# SEED: 1, FOLD: 3, SCORED_ONLY, EPOCH: 23, train_loss: 0.017125, valid_loss: 0.017471
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 0, train_loss: 0.494471, valid_loss: 0.021590
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 1, train_loss: 0.016900, valid_loss: 0.011596
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 2, train_loss: 0.014800, valid_loss: 0.011257
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 3, train_loss: 0.014110, valid_loss: 0.011604
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 4, train_loss: 0.013938, valid_loss: 0.010367
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 5, train_loss: 0.013955, valid_loss: 0.010456
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 6, train_loss: 0.013894, valid_loss: 0.010593
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 7, train_loss: 0.013957, valid_loss: 0.010589
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 8, train_loss: 0.013869, valid_loss: 0.010445
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 9, train_loss: 0.013887, valid_loss: 0.010345
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 10, train_loss: 0.013857, valid_loss: 0.010471
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 11, train_loss: 0.013844, valid_loss: 0.010402
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 12, train_loss: 0.013845, valid_loss: 0.010380
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 13, train_loss: 0.013785, valid_loss: 0.010374
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 14, train_loss: 0.013732, valid_loss: 0.010250
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 15, train_loss: 0.013671, valid_loss: 0.010215
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 16, train_loss: 0.013634, valid_loss: 0.010209
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 17, train_loss: 0.013537, valid_loss: 0.010131
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 18, train_loss: 0.013434, valid_loss: 0.010048
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 19, train_loss: 0.013308, valid_loss: 0.010031
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 20, train_loss: 0.013162, valid_loss: 0.009991
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 21, train_loss: 0.013043, valid_loss: 0.009947
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 22, train_loss: 0.012921, valid_loss: 0.009904
# SEED: 1, FOLD: 4, ALL_TARGETS, EPOCH: 23, train_loss: 0.012854, valid_loss: 0.009902
# SEED: 1, FOLD: 4, SCORED_ONLY, EPOCH: 0, train_loss: 0.644199, valid_loss: 0.261290
# SEED: 1, FOLD: 4, SCORED_ONLY, EPOCH: 1, train_loss: 0.059041, valid_loss: 0.019841
# SEED: 1, FOLD: 4, SCORED_ONLY, EPOCH: 2, train_loss: 0.020827, valid_loss: 0.017530
# SEED: 1, FOLD: 4, SCORED_ONLY, EPOCH: 3, train_loss: 0.019760, valid_loss: 0.017233
# SEED: 1, FOLD: 4, SCORED_ONLY, EPOCH: 4, train_loss: 0.023032, valid_loss: 0.017031
# SEED: 1, FOLD: 4, SCORED_ONLY, EPOCH: 5, train_loss: 0.019485, valid_loss: 0.017033
# SEED: 1, FOLD: 4, SCORED_ONLY, EPOCH: 6, train_loss: 0.019332, valid_loss: 0.017016
# SEED: 1, FOLD: 4, SCORED_ONLY, EPOCH: 7, train_loss: 0.019236, valid_loss: 0.016970
# SEED: 1, FOLD: 4, SCORED_ONLY, EPOCH: 8, train_loss: 0.019492, valid_loss: 0.017117
# SEED: 1, FOLD: 4, SCORED_ONLY, EPOCH: 9, train_loss: 0.019230, valid_loss: 0.017065
# SEED: 1, FOLD: 4, SCORED_ONLY, EPOCH: 10, train_loss: 0.019152, valid_loss: 0.016949
# SEED: 1, FOLD: 4, SCORED_ONLY, EPOCH: 11, train_loss: 0.019055, valid_loss: 0.017074
# SEED: 1, FOLD: 4, SCORED_ONLY, EPOCH: 12, train_loss: 0.019360, valid_loss: 0.016966
# SEED: 1, FOLD: 4, SCORED_ONLY, EPOCH: 13, train_loss: 0.019037, valid_loss: 0.017058
# SEED: 1, FOLD: 4, SCORED_ONLY, EPOCH: 14, train_loss: 0.018865, valid_loss: 0.016935
# ...
# SEED: 6, FOLD: 3, ALL_TARGETS, EPOCH: 4, train_loss: 0.014165, valid_loss: 0.010816
# SEED: 6, FOLD: 3, ALL_TARGETS, EPOCH: 5, train_loss: 0.014131, valid_loss: 0.010536
# SEED: 6, FOLD: 3, ALL_TARGETS, EPOCH: 6, train_loss: 0.013905, valid_loss: 0.010476
# SEED: 6, FOLD: 3, ALL_TARGETS, EPOCH: 7, train_loss: 0.013914, valid_loss: 0.010568
# SEED: 6, FOLD: 3, ALL_TARGETS, EPOCH: 8, train_loss: 0.013914, valid_loss: 0.010618
# SEED: 6, FOLD: 3, ALL_TARGETS, EPOCH: 9, train_loss: 0.013869, valid_loss: 0.010464
# SEED: 6, FOLD: 3, ALL_TARGETS, EPOCH: 10, train_loss: 0.013879, valid_loss: 0.010457
# SEED: 6, FOLD: 3, ALL_TARGETS, EPOCH: 11, train_loss: 0.013847, valid_loss: 0.010596
# SEED: 6, FOLD: 3, ALL_TARGETS, EPOCH: 12, train_loss: 0.013828, valid_loss: 0.010517
# SEED: 6, FOLD: 3, ALL_TARGETS, EPOCH: 13, train_loss: 0.013789, valid_loss: 0.010628
# SEED: 6, FOLD: 3, ALL_TARGETS, EPOCH: 14, train_loss: 0.013738, valid_loss: 0.010445
# SEED: 6, FOLD: 3, ALL_TARGETS, EPOCH: 15, train_loss: 0.013674, valid_loss: 0.010466
# SEED: 6, FOLD: 3, ALL_TARGETS, EPOCH: 16, train_loss: 0.013607, valid_loss: 0.010332
# SEED: 6, FOLD: 3, ALL_TARGETS, EPOCH: 17, train_loss: 0.013532, valid_loss: 0.010305
# SEED: 6, FOLD: 3, ALL_TARGETS, EPOCH: 18, train_loss: 0.013424, valid_loss: 0.010261
# SEED: 6, FOLD: 3, ALL_TARGETS, EPOCH: 19, train_loss: 0.013348, valid_loss: 0.010157
# SEED: 6, FOLD: 3, ALL_TARGETS, EPOCH: 20, train_loss: 0.013184, valid_loss: 0.010137
# SEED: 6, FOLD: 3, ALL_TARGETS, EPOCH: 21, train_loss: 0.013052, valid_loss: 0.010068
# SEED: 6, FOLD: 3, ALL_TARGETS, EPOCH: 22, train_loss: 0.012921, valid_loss: 0.010053
# SEED: 6, FOLD: 3, ALL_TARGETS, EPOCH: 23, train_loss: 0.012856, valid_loss: 0.010034
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 0, train_loss: 0.640921, valid_loss: 0.263256
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 1, train_loss: 0.058889, valid_loss: 0.020016
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 2, train_loss: 0.020739, valid_loss: 0.018125
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 3, train_loss: 0.019696, valid_loss: 0.017724
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 4, train_loss: 0.022196, valid_loss: 0.017532
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 5, train_loss: 0.019444, valid_loss: 0.017607
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 6, train_loss: 0.019327, valid_loss: 0.017740
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 7, train_loss: 0.019192, valid_loss: 0.017665
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 8, train_loss: 0.019349, valid_loss: 0.017588
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 9, train_loss: 0.019158, valid_loss: 0.017621
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 10, train_loss: 0.019081, valid_loss: 0.017573
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 11, train_loss: 0.018977, valid_loss: 0.017497
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 12, train_loss: 0.019238, valid_loss: 0.017439
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 13, train_loss: 0.019029, valid_loss: 0.017581
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 14, train_loss: 0.018812, valid_loss: 0.017480
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 15, train_loss: 0.018649, valid_loss: 0.017549
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 16, train_loss: 0.019043, valid_loss: 0.017486
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 17, train_loss: 0.018555, valid_loss: 0.017488
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 18, train_loss: 0.018186, valid_loss: 0.017396
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 19, train_loss: 0.017799, valid_loss: 0.017494
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 20, train_loss: 0.017452, valid_loss: 0.017481
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 21, train_loss: 0.017152, valid_loss: 0.017508
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 22, train_loss: 0.016949, valid_loss: 0.017536
# SEED: 6, FOLD: 3, SCORED_ONLY, EPOCH: 23, train_loss: 0.016830, valid_loss: 0.017517
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 0, train_loss: 0.495499, valid_loss: 0.021592
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 1, train_loss: 0.016394, valid_loss: 0.013057
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 2, train_loss: 0.014274, valid_loss: 0.012042
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 3, train_loss: 0.014409, valid_loss: 0.013407
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 4, train_loss: 0.014046, valid_loss: 0.011974
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 5, train_loss: 0.013996, valid_loss: 0.012463
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 6, train_loss: 0.013888, valid_loss: 0.011346
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 7, train_loss: 0.013881, valid_loss: 0.012002
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 8, train_loss: 0.013800, valid_loss: 0.011506
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 9, train_loss: 0.013813, valid_loss: 0.011447
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 10, train_loss: 0.013849, valid_loss: 0.011218
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 11, train_loss: 0.013847, valid_loss: 0.011004
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 12, train_loss: 0.013797, valid_loss: 0.011066
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 13, train_loss: 0.013793, valid_loss: 0.011077
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 14, train_loss: 0.013676, valid_loss: 0.011001
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 15, train_loss: 0.013640, valid_loss: 0.011026
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 16, train_loss: 0.013561, valid_loss: 0.010869
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 17, train_loss: 0.013560, valid_loss: 0.010858
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 18, train_loss: 0.013513, valid_loss: 0.010823
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 19, train_loss: 0.013318, valid_loss: 0.010757
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 20, train_loss: 0.013163, valid_loss: 0.010665
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 21, train_loss: 0.013033, valid_loss: 0.010594
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 22, train_loss: 0.012941, valid_loss: 0.010599
# SEED: 6, FOLD: 4, ALL_TARGETS, EPOCH: 23, train_loss: 0.012862, valid_loss: 0.010619
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 0, train_loss: 0.641799, valid_loss: 0.257695
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 1, train_loss: 0.058491, valid_loss: 0.020462
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 2, train_loss: 0.020981, valid_loss: 0.018504
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 3, train_loss: 0.020025, valid_loss: 0.017986
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 4, train_loss: 0.022185, valid_loss: 0.017939
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 5, train_loss: 0.019645, valid_loss: 0.018126
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 6, train_loss: 0.019536, valid_loss: 0.018104
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 7, train_loss: 0.019550, valid_loss: 0.018061
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 8, train_loss: 0.019660, valid_loss: 0.018008
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 9, train_loss: 0.019510, valid_loss: 0.017846
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 10, train_loss: 0.019352, valid_loss: 0.018102
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 11, train_loss: 0.019289, valid_loss: 0.017782
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 12, train_loss: 0.019651, valid_loss: 0.017848
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 13, train_loss: 0.019280, valid_loss: 0.017915
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 14, train_loss: 0.019039, valid_loss: 0.017854
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 15, train_loss: 0.019028, valid_loss: 0.017796
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 16, train_loss: 0.019273, valid_loss: 0.018180
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 17, train_loss: 0.018856, valid_loss: 0.017781
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 18, train_loss: 0.018408, valid_loss: 0.017711
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 19, train_loss: 0.018124, valid_loss: 0.017736
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 20, train_loss: 0.017872, valid_loss: 0.017756
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 21, train_loss: 0.017625, valid_loss: 0.017809
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 22, train_loss: 0.017427, valid_loss: 0.017877
# SEED: 6, FOLD: 4, SCORED_ONLY, EPOCH: 23, train_loss: 0.017335, valid_loss: 0.017842
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 0, train_loss: 0.494151, valid_loss: 0.028572
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 1, train_loss: 0.016994, valid_loss: 0.012404
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 2, train_loss: 0.014627, valid_loss: 0.011205
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 3, train_loss: 0.013914, valid_loss: 0.011124
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 4, train_loss: 0.014174, valid_loss: 0.011344
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 5, train_loss: 0.013892, valid_loss: 0.012042
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 6, train_loss: 0.013859, valid_loss: 0.011119
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 7, train_loss: 0.013860, valid_loss: 0.011262
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 8, train_loss: 0.013823, valid_loss: 0.010967
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 9, train_loss: 0.013838, valid_loss: 0.011377
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 10, train_loss: 0.013775, valid_loss: 0.011193
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 11, train_loss: 0.013772, valid_loss: 0.011035
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 12, train_loss: 0.013716, valid_loss: 0.010924
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 13, train_loss: 0.013697, valid_loss: 0.011079
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 14, train_loss: 0.013628, valid_loss: 0.011050
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 15, train_loss: 0.013604, valid_loss: 0.010875
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 16, train_loss: 0.013517, valid_loss: 0.010804
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 17, train_loss: 0.013425, valid_loss: 0.010782
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 18, train_loss: 0.013336, valid_loss: 0.010734
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 19, train_loss: 0.013194, valid_loss: 0.010714
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 20, train_loss: 0.013080, valid_loss: 0.010635
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 21, train_loss: 0.012936, valid_loss: 0.010621
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 22, train_loss: 0.012840, valid_loss: 0.010580
# SEED: 6, FOLD: 5, ALL_TARGETS, EPOCH: 23, train_loss: 0.012758, valid_loss: 0.010634
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 0, train_loss: 0.641880, valid_loss: 0.254440
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 1, train_loss: 0.058082, valid_loss: 0.020111
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 2, train_loss: 0.020793, valid_loss: 0.017768
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 3, train_loss: 0.019746, valid_loss: 0.017622
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 4, train_loss: 0.023181, valid_loss: 0.017566
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 5, train_loss: 0.019507, valid_loss: 0.017475
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 6, train_loss: 0.019331, valid_loss: 0.017588
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 7, train_loss: 0.019255, valid_loss: 0.017576
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 8, train_loss: 0.019490, valid_loss: 0.017507
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 9, train_loss: 0.019280, valid_loss: 0.017433
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 10, train_loss: 0.019155, valid_loss: 0.017424
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 11, train_loss: 0.019036, valid_loss: 0.017498
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 12, train_loss: 0.019384, valid_loss: 0.017447
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 13, train_loss: 0.019066, valid_loss: 0.017411
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 14, train_loss: 0.018902, valid_loss: 0.017455
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 15, train_loss: 0.018728, valid_loss: 0.017380
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 16, train_loss: 0.019015, valid_loss: 0.017466
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 17, train_loss: 0.018639, valid_loss: 0.017392
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 18, train_loss: 0.018262, valid_loss: 0.017273
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 19, train_loss: 0.017902, valid_loss: 0.017384
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 20, train_loss: 0.017535, valid_loss: 0.017378
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 21, train_loss: 0.017255, valid_loss: 0.017347
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 22, train_loss: 0.017073, valid_loss: 0.017380
# SEED: 6, FOLD: 5, SCORED_ONLY, EPOCH: 23, train_loss: 0.017018, valid_loss: 0.017367
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 0, train_loss: 0.497248, valid_loss: 0.021597
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 1, train_loss: 0.016796, valid_loss: 0.011315
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 2, train_loss: 0.014476, valid_loss: 0.010390
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 3, train_loss: 0.014155, valid_loss: 0.010355
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 4, train_loss: 0.014060, valid_loss: 0.010334
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 5, train_loss: 0.013964, valid_loss: 0.010474
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 6, train_loss: 0.013913, valid_loss: 0.010246
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 7, train_loss: 0.013972, valid_loss: 0.010608
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 8, train_loss: 0.013926, valid_loss: 0.010395
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 9, train_loss: 0.013877, valid_loss: 0.010485
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 10, train_loss: 0.013870, valid_loss: 0.010372
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 11, train_loss: 0.013862, valid_loss: 0.010421
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 12, train_loss: 0.013835, valid_loss: 0.010277
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 13, train_loss: 0.013795, valid_loss: 0.010668
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 14, train_loss: 0.013759, valid_loss: 0.010218
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 15, train_loss: 0.013687, valid_loss: 0.010093
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 16, train_loss: 0.013628, valid_loss: 0.010082
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 17, train_loss: 0.013549, valid_loss: 0.010000
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 18, train_loss: 0.013425, valid_loss: 0.009954
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 19, train_loss: 0.013318, valid_loss: 0.009970
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 20, train_loss: 0.013172, valid_loss: 0.009853
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 21, train_loss: 0.013036, valid_loss: 0.009857
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 22, train_loss: 0.012900, valid_loss: 0.009814
# SEED: 6, FOLD: 6, ALL_TARGETS, EPOCH: 23, train_loss: 0.012844, valid_loss: 0.009806
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 0, train_loss: 0.639265, valid_loss: 0.264115
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 1, train_loss: 0.059042, valid_loss: 0.019832
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 2, train_loss: 0.020658, valid_loss: 0.017621
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 3, train_loss: 0.019644, valid_loss: 0.017323
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 4, train_loss: 0.022314, valid_loss: 0.017124
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 5, train_loss: 0.019447, valid_loss: 0.017115
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 6, train_loss: 0.019264, valid_loss: 0.017111
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 7, train_loss: 0.019128, valid_loss: 0.017046
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 8, train_loss: 0.019366, valid_loss: 0.017199
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 9, train_loss: 0.019185, valid_loss: 0.017090
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 10, train_loss: 0.019094, valid_loss: 0.017076
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 11, train_loss: 0.018965, valid_loss: 0.017047
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 12, train_loss: 0.019225, valid_loss: 0.017162
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 13, train_loss: 0.018950, valid_loss: 0.017064
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 14, train_loss: 0.018736, valid_loss: 0.017140
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 15, train_loss: 0.018569, valid_loss: 0.017017
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 16, train_loss: 0.018981, valid_loss: 0.016947
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 17, train_loss: 0.018546, valid_loss: 0.017008
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 18, train_loss: 0.018122, valid_loss: 0.017030
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 19, train_loss: 0.017756, valid_loss: 0.017031
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 20, train_loss: 0.017416, valid_loss: 0.017045
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 21, train_loss: 0.017106, valid_loss: 0.017030
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 22, train_loss: 0.016886, valid_loss: 0.017003
# SEED: 6, FOLD: 6, SCORED_ONLY, EPOCH: 23, train_loss: 0.016800, valid_loss: 0.016992
# 1:18:16.152526

# %%
# obtain CV score

valid_results = train_targets_scored.drop(columns=target_cols).merge(train[['sig_id']+target_cols], on='sig_id', how='left').fillna(0) # remarks: here already set 0 for ctrl 

y_true = train_targets_scored[target_cols].values
y_pred = valid_results[target_cols].values

score = 0

for i in range(len(target_cols)):
    score += log_loss(y_true[:, i], y_pred[:, i])

print("CV log_loss: ", score / y_pred.shape[1])
# Out:
# CV log_loss:  0.015603867671285977

# %% [markdown]
# # Submission

# %%
# create submission file
sub1 = sample_submission.drop(columns=target_cols).merge(test[['sig_id']+target_cols], on='sig_id', how='left').fillna(0)
sub1.to_csv('/kaggle/working/submission.csv', index = None)
print(sub1.shape)
sub1.head()
# Out:
# (3982, 207)
#          sig_id  5-alpha_reductase_inhibitor  11-beta-hsd1_inhibitor  \
# 0  id_0004d9e33                     0.000902                0.000955
# 1  id_001897cda                     0.000626                0.000829
# 2  id_002429b5b                     0.000000                0.000000
# 3  id_00276f245                     0.000744                0.000865
# 4  id_0027f1083                     0.002174                0.001318
#
#    acat_inhibitor  acetylcholine_receptor_agonist  \
# 0        0.002047                        0.017687
# 1        0.001074                        0.002075
# 2        0.000000                        0.000000
# 3        0.001587                        0.011485
# 4        0.001602                        0.020017
#
#    acetylcholine_receptor_antagonist  acetylcholinesterase_inhibitor  \
# 0                           0.021500                        0.004837
# 1                           0.001293                        0.001704
# 2                           0.000000                        0.000000
# 3                           0.020147                        0.004411
# 4                           0.025909                        0.005222
#
#    adenosine_receptor_agonist  adenosine_receptor_antagonist  \
# 0                    0.003854                       0.005194
# 1                    0.003664                       0.014857
# 2                    0.000000                       0.000000
# 3                    0.003006                       0.005945
# 4                    0.003786                       0.002311
#
#    adenylyl_cyclase_activator  ...  tropomyosin_receptor_kinase_inhibitor  \
# 0                    0.000397  ...                               0.001267
# 1                    0.026774  ...                               0.000581
# 2                    0.000000  ...                               0.000000
# 3                    0.000454  ...                               0.000594
# 4                    0.000471  ...                               0.000888
#
#    trpv_agonist  trpv_antagonist  tubulin_inhibitor  \
# 0      0.000958         0.004336           0.001701
# 1      0.000903         0.001758           0.000693
# 2      0.000000         0.000000           0.000000
# 3      0.001210         0.002089           0.003233
# 4      0.000812         0.002916           0.001612
#
#    tyrosine_kinase_inhibitor  ubiquitin_specific_protease_inhibitor  \
# 0                   0.001320                               0.000593
# 1                   0.010186                               0.000667
# 2                   0.000000                               0.000000
# 3                   0.004167                               0.000535
# 4                   0.001579                               0.000635
#
#    vegfr_inhibitor  vitamin_b  vitamin_d_receptor_agonist  wnt_inhibitor
# 0         0.001325   0.002217                    0.002516       0.001712
# 1         0.005990   0.001720                    0.001191       0.003740
# 2         0.000000   0.000000                    0.000000       0.000000
# 3         0.001421   0.001841                    0.001978       0.001835
# 4         0.001098   0.002022                    0.000831       0.001618
#
# [5 rows x 207 columns]
